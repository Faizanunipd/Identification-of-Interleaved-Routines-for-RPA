# %%
# !pip install python-docx

# %%
import os
import random
import pandas as pd
from docx import Document
from docx.enum.text import WD_ALIGN_PARAGRAPH


from Utils.utils1 import *
import Utils.graph_functions as grf

import warnings
warnings.filterwarnings('ignore')

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import normalized_mutual_info_score

import networkx as nx
from infomap import Infomap
from itertools import combinations
from collections import defaultdict
import community as community_louvain

import pm4py
from pm4py.objects.log.util import dataframe_utils
from pm4py.algo.discovery.dfg import algorithm as dfg_discovery
from pm4py.objects.conversion.log import converter as log_converter

# %%
filename = "Cluster-Results.docx"
Combination = 2
if os.path.exists(filename):
    doc = Document(filename)
else:
    doc = Document()
    centered_heading = doc.add_heading('Cluster Results', level=1)
    centered_heading.alignment = WD_ALIGN_PARAGRAPH.CENTER

centered_heading = doc.add_heading(f'Iteration {Combination}', level=3)
centered_heading.alignment = WD_ALIGN_PARAGRAPH.CENTER

# %%
# === RUN MODE OPTIONS ===
# 1: Use already saved logs
# 2: Use specified routines
# 3: New random selection
run_mode = 1  # Set to 1, 2, or 3
specified_routines = [52, 66, 85]  # Only used if run_mode == 2
num_iterations = 1 if run_mode == 2 else 100  # Only one iteration for specified routines

technique = "Our"
variant_count = 5

noise_level = 0.1
results_dir = f"out/results/Noise_{noise_level}_variant"
os.makedirs(results_dir) if not os.path.exists(results_dir) else None

input_dir = "Saved_Logs"
output_dir = f"Transformed_Logs_and_Results - Ind Noise/{technique}/Transformed_Log_With_Noise_{noise_level}"
logs = pd.read_csv(f"{input_dir}/gt_labeled_all_routine_logs.csv", low_memory=False)

interleaved_results = []
for i in range(1, num_iterations + 1):
    print("="*5, "Start Iteration", i, "="*5)
    all_results = []
    all_iteration_metadata = []  # Add this line to collect metadata
    for variant in range(1, variant_count+1):
        print(f"\n\n{'='*5} Start Iteration {i} with variant {variant} {'='*5}")
        if run_mode == 1:
            # Option 1: Use already saved logs
            segment_log = pd.read_csv(f"{output_dir}/log{i}/segment_log{i}_{variant}.csv")
            # random_logs = pd.read_csv(f"{output_dir}/log{i}/unsegment_log{i}_{variant}.csv")
            # random_numbers = list(segment_log['routine_type'].unique())
            # iteration_metadata = None  # No metadata for saved logs
        elif run_mode == 2:
            # Option 2: Use specified routines (only one iteration)
            segment_log, random_logs, random_numbers, doc, iteration_metadata = process_random_logs(
                logs, document=doc, variance_criteria='max', specified_routines=specified_routines
            )
            if segment_log is None:
                print("Specified routines did not yield enough traces. Exiting.")
                break
        else:
            print("\n","="*5, f"Start Iteration {i}:", "="*5)
            # Option 3: New random selection (current behavior)
            segment_log, random_logs, random_numbers, doc, iteration_metadata = process_random_logs(
                logs, document=doc, variance_criteria='min'
            )
            segment_log.to_csv(f"{output_dir}/segment_log{i}.csv", index=False)
            random_logs.to_csv(f"{output_dir}/unsegment_log{i}.csv", index=False)

        trace_interleaved_counts = count_trace_interleaving_cases(segment_log)
        trace_interleaved_counts = update_avg_counts(trace_interleaved_counts)
        trace_interleaved_counts['iteration'] = f"iteration_{i}_{variant}"
        interleaved_results.append(trace_interleaved_counts)
        
#         # # Store metadata for Excel export
#         all_iteration_metadata.append(iteration_metadata)
    
#         doc = plot_interleaved_routines(segment_log, random_numbers, doc, image_path=f"out/plots/interleaved_routines_plot{i}.png", interleaved_only=False)
#         plot_trace_interleaving_cases(segment_log, image_path=f"out/plots/trace_interleaving_cases_bar{i}.png")

#         random_logs = random_logs[['case:concept:name', 'concept:name', 'time:timestamp']]
#         dfg = grf.discover_dfg(random_logs)
#         G_Directed = grf.get_Network_Graph(dfg, output_filename=f"Graph_Matrix_Directed{i}.csv")
#         G_Directed_Scored2 = grf.get_scored2_grpah_directed(G_Directed, output_filename=f"Graph_Matrix_UnDirected{i}.csv")
    
#         doc.add_heading('Infomap Clustering with scored2 directed graph', level=2)
#         infomap_clusters, doc = grf.infomap_clustering(G_Directed_Scored2, document=doc, MRT=4.0)
    
#         results_dict = evaluate_clusters_with_jc_variant(infomap_clusters, segment_log)
#         results_dict = append_averages_to_results(results_dict, random_numbers)
#         all_results.append(results_dict)
    
#         doc = display_and_export_results_doc(results_dict, doc, table_title="Cluster Evaluation Summary (Infomap)")

#     results_file_name = f'{technique}_results_log{i}.xlsx'
#     display_and_export_results_xlx(all_results, all_iteration_metadata, results_dir, results_file_name)
# analyze_jc_across_all_logs(noise_level=str(f"{noise_level}_variant"))
# Out:
# ===== Start Iteration 1 =====
#
#
# ===== Start Iteration 1 with variant 1 =====
#
# Not interleaved: 10
# Interleaved with one: 52
# Interleaved with two or more: 1145
#
#
#
# ===== Start Iteration 1 with variant 2 =====
#
# Not interleaved: 13
# Interleaved with one: 99
# Interleaved with two or more: 1095
#
#
#
# ===== Start Iteration 1 with variant 3 =====
#
# Not interleaved: 26
# Interleaved with one: 256
# Interleaved with two or more: 925
#
#
#
# ===== Start Iteration 1 with variant 4 =====
#
# Not interleaved: 22
# Interleaved with one: 125
# Interleaved with two or more: 1060
#
#
#
# ===== Start Iteration 1 with variant 5 =====
#
# Not interleaved: 23
# Interleaved with one: 268
# Interleaved with two or more: 916
#
# ===== Start Iteration 2 =====
#
#
# ===== Start Iteration 2 with variant 1 =====
#
# Not interleaved: 45
# Interleaved with one: 157
# Interleaved with two or more: 729
#
#
#
# ===== Start Iteration 2 with variant 2 =====
#
# Not interleaved: 89
# Interleaved with one: 168
# Interleaved with two or more: 674
#
#
#
# ===== Start Iteration 2 with variant 3 =====
#
# Not interleaved: 35
# Interleaved with one: 109
# Interleaved with two or more: 787
#
#
#
# ===== Start Iteration 2 with variant 4 =====
#
# Not interleaved: 33
# Interleaved with one: 138
# Interleaved with two or more: 760
#
#
#
# ===== Start Iteration 2 with variant 5 =====
#
# Not interleaved: 47
# Interleaved with one: 267
# Interleaved with two or more: 617
#
# ===== Start Iteration 3 =====
#
#
# ===== Start Iteration 3 with variant 1 =====
#
# Not interleaved: 31
# Interleaved with one: 61
# Interleaved with two or more: 611
#
#
#
# ===== Start Iteration 3 with variant 2 =====
#
# Not interleaved: 60
# Interleaved with one: 174
# Interleaved with two or more: 469
#
#
#
# ===== Start Iteration 3 with variant 3 =====
#
# Not interleaved: 29
# Interleaved with one: 366
# Interleaved with two or more: 308
#
#
#
# ===== Start Iteration 3 with variant 4 =====
#
# Not interleaved: 22
# Interleaved with one: 89
# Interleaved with two or more: 592
#
#
#
# ===== Start Iteration 3 with variant 5 =====
#
# Not interleaved: 37
# Interleaved with one: 221
# Interleaved with two or more: 445
#
# ===== Start Iteration 4 =====
#
#
# ===== Start Iteration 4 with variant 1 =====
#
# Not interleaved: 6
# Interleaved with one: 43
# Interleaved with two or more: 902
#
#
#
# ===== Start Iteration 4 with variant 2 =====
#
# Not interleaved: 67
# Interleaved with one: 130
# Interleaved with two or more: 754
#
#
#
# ===== Start Iteration 4 with variant 3 =====
#
# Not interleaved: 84
# Interleaved with one: 304
# Interleaved with two or more: 563
#
#
#
# ===== Start Iteration 4 with variant 4 =====
#
# Not interleaved: 33
# Interleaved with one: 147
# Interleaved with two or more: 771
#
#
#
# ===== Start Iteration 4 with variant 5 =====
#
# Not interleaved: 49
# Interleaved with one: 124
# Interleaved with two or more: 778
#
# ===== Start Iteration 5 =====
#
#
# ===== Start Iteration 5 with variant 1 =====
#
# Not interleaved: 1
# Interleaved with one: 74
# Interleaved with two or more: 1127
#
#
#
# ===== Start Iteration 5 with variant 2 =====
#
# Not interleaved: 1
# Interleaved with one: 207
# Interleaved with two or more: 994
#
#
#
# ===== Start Iteration 5 with variant 3 =====
#
# Not interleaved: 1
# Interleaved with one: 75
# Interleaved with two or more: 1126
#
#
#
# ===== Start Iteration 5 with variant 4 =====
#
# Not interleaved: 2
# Interleaved with one: 37
# Interleaved with two or more: 1163
#
#
#
# ===== Start Iteration 5 with variant 5 =====
#
# Not interleaved: 9
# Interleaved with one: 167
# Interleaved with two or more: 1026
#
# ===== Start Iteration 6 =====
#
#
# ===== Start Iteration 6 with variant 1 =====
#
# Not interleaved: 28
# Interleaved with one: 158
# Interleaved with two or more: 438
#
#
#
# ===== Start Iteration 6 with variant 2 =====
#
# Not interleaved: 45
# Interleaved with one: 168
# Interleaved with two or more: 411
#
#
#
# ===== Start Iteration 6 with variant 3 =====
#
# Not interleaved: 88
# Interleaved with one: 150
# Interleaved with two or more: 386
#
#
#
# ===== Start Iteration 6 with variant 4 =====
#
# Not interleaved: 34
# Interleaved with one: 116
# Interleaved with two or more: 474
#
#
#
# ===== Start Iteration 6 with variant 5 =====
#
# Not interleaved: 17
# Interleaved with one: 128
# Interleaved with two or more: 479
#
# ===== Start Iteration 7 =====
#
#
# ===== Start Iteration 7 with variant 1 =====
#
# Not interleaved: 1
# Interleaved with one: 38
# Interleaved with two or more: 1547
#
#
#
# ===== Start Iteration 7 with variant 2 =====
#
# Not interleaved: 13
# Interleaved with one: 77
# Interleaved with two or more: 1496
#
#
#
# ===== Start Iteration 7 with variant 3 =====
#
# Not interleaved: 2
# Interleaved with one: 71
# Interleaved with two or more: 1513
#
#
#
# ===== Start Iteration 7 with variant 4 =====
#
# Not interleaved: 0
# Interleaved with one: 27
# Interleaved with two or more: 1559
#
#
#
# ===== Start Iteration 7 with variant 5 =====
#
# Not interleaved: 7
# Interleaved with one: 54
# Interleaved with two or more: 1525
#
# ===== Start Iteration 8 =====
#
#
# ===== Start Iteration 8 with variant 1 =====
#
# Not interleaved: 0
# Interleaved with one: 30
# Interleaved with two or more: 1048
#
#
#
# ===== Start Iteration 8 with variant 2 =====
#
# Not interleaved: 7
# Interleaved with one: 99
# Interleaved with two or more: 972
#
#
#
# ===== Start Iteration 8 with variant 3 =====
#
# Not interleaved: 9
# Interleaved with one: 159
# Interleaved with two or more: 910
#
#
#
# ===== Start Iteration 8 with variant 4 =====
#
# Not interleaved: 6
# Interleaved with one: 159
# Interleaved with two or more: 913
#
#
#
# ===== Start Iteration 8 with variant 5 =====
#
# Not interleaved: 27
# Interleaved with one: 190
# Interleaved with two or more: 861
#
# ===== Start Iteration 9 =====
#
#
# ===== Start Iteration 9 with variant 1 =====
#
# Not interleaved: 36
# Interleaved with one: 128
# Interleaved with two or more: 185
#
#
#
# ===== Start Iteration 9 with variant 2 =====
#
# Not interleaved: 25
# Interleaved with one: 124
# Interleaved with two or more: 200
#
#
#
# ===== Start Iteration 9 with variant 3 =====
#
# Not interleaved: 32
# Interleaved with one: 174
# Interleaved with two or more: 143
#
#
#
# ===== Start Iteration 9 with variant 4 =====
#
# Not interleaved: 20
# Interleaved with one: 167
# Interleaved with two or more: 162
#
#
#
# ===== Start Iteration 9 with variant 5 =====
#
# Not interleaved: 25
# Interleaved with one: 200
# Interleaved with two or more: 124
#
# ===== Start Iteration 10 =====
#
#
# ===== Start Iteration 10 with variant 1 =====
#
# Not interleaved: 1
# Interleaved with one: 82
# Interleaved with two or more: 933
#
#
#
# ===== Start Iteration 10 with variant 2 =====
#
# Not interleaved: 2
# Interleaved with one: 117
# Interleaved with two or more: 897
#
#
#
# ===== Start Iteration 10 with variant 3 =====
#
# Not interleaved: 0
# Interleaved with one: 163
# Interleaved with two or more: 853
#
#
#
# ===== Start Iteration 10 with variant 4 =====
#
# Not interleaved: 1
# Interleaved with one: 169
# Interleaved with two or more: 846
#
#
#
# ===== Start Iteration 10 with variant 5 =====
#
# Not interleaved: 1
# Interleaved with one: 160
# Interleaved with two or more: 855
#
# ===== Start Iteration 11 =====
#
#
# ===== Start Iteration 11 with variant 1 =====
#
# Not interleaved: 18
# Interleaved with one: 139
# Interleaved with two or more: 1137
#
#
#
# ===== Start Iteration 11 with variant 2 =====
#
# Not interleaved: 10
# Interleaved with one: 81
# Interleaved with two or more: 1203
#
#
#
# ===== Start Iteration 11 with variant 3 =====
#
# Not interleaved: 68
# Interleaved with one: 251
# Interleaved with two or more: 975
#
#
#
# ===== Start Iteration 11 with variant 4 =====
#
# Not interleaved: 19
# Interleaved with one: 138
# Interleaved with two or more: 1137
#
#
#
# ===== Start Iteration 11 with variant 5 =====
#
# Not interleaved: 22
# Interleaved with one: 238
# Interleaved with two or more: 1034
#
# ===== Start Iteration 12 =====
#
#
# ===== Start Iteration 12 with variant 1 =====
#
# Not interleaved: 21
# Interleaved with one: 74
# Interleaved with two or more: 953
#
#
#
# ===== Start Iteration 12 with variant 2 =====
#
# Not interleaved: 21
# Interleaved with one: 130
# Interleaved with two or more: 897
#
#
#
# ===== Start Iteration 12 with variant 3 =====
#
# Not interleaved: 3
# Interleaved with one: 147
# Interleaved with two or more: 898
#
#
#
# ===== Start Iteration 12 with variant 4 =====
#
# Not interleaved: 11
# Interleaved with one: 92
# Interleaved with two or more: 945
#
#
#
# ===== Start Iteration 12 with variant 5 =====
#
# Not interleaved: 6
# Interleaved with one: 111
# Interleaved with two or more: 931
#
# ===== Start Iteration 13 =====
#
#
# ===== Start Iteration 13 with variant 1 =====
#
# Not interleaved: 259
# Interleaved with one: 206
# Interleaved with two or more: 294
#
#
#
# ===== Start Iteration 13 with variant 2 =====
#
# Not interleaved: 260
# Interleaved with one: 205
# Interleaved with two or more: 294
#
#
#
# ===== Start Iteration 13 with variant 3 =====
#
# Not interleaved: 259
# Interleaved with one: 207
# Interleaved with two or more: 293
#
#
#
# ===== Start Iteration 13 with variant 4 =====
#
# Not interleaved: 259
# Interleaved with one: 207
# Interleaved with two or more: 293
#
#
#
# ===== Start Iteration 13 with variant 5 =====
#
# Not interleaved: 256
# Interleaved with one: 208
# Interleaved with two or more: 295
#
# ===== Start Iteration 14 =====
#
#
# ===== Start Iteration 14 with variant 1 =====
#
# Not interleaved: 76
# Interleaved with one: 170
# Interleaved with two or more: 146
#
#
#
# ===== Start Iteration 14 with variant 2 =====
#
# Not interleaved: 27
# Interleaved with one: 182
# Interleaved with two or more: 183
#
#
#
# ===== Start Iteration 14 with variant 3 =====
#
# Not interleaved: 32
# Interleaved with one: 151
# Interleaved with two or more: 209
#
#
#
# ===== Start Iteration 14 with variant 4 =====
#
# Not interleaved: 40
# Interleaved with one: 161
# Interleaved with two or more: 191
#
#
#
# ===== Start Iteration 14 with variant 5 =====
#
# Not interleaved: 76
# Interleaved with one: 212
# Interleaved with two or more: 104
#
# ===== Start Iteration 15 =====
#
#
# ===== Start Iteration 15 with variant 1 =====
#
# Not interleaved: 147
# Interleaved with one: 666
# Interleaved with two or more: 228
#
#
#
# ===== Start Iteration 15 with variant 2 =====
#
# Not interleaved: 83
# Interleaved with one: 302
# Interleaved with two or more: 656
#
#
#
# ===== Start Iteration 15 with variant 3 =====
#
# Not interleaved: 44
# Interleaved with one: 258
# Interleaved with two or more: 739
#
#
#
# ===== Start Iteration 15 with variant 4 =====
#
# Not interleaved: 104
# Interleaved with one: 415
# Interleaved with two or more: 522
#
#
#
# ===== Start Iteration 15 with variant 5 =====
#
# Not interleaved: 153
# Interleaved with one: 542
# Interleaved with two or more: 346
#
# ===== Start Iteration 16 =====
#
#
# ===== Start Iteration 16 with variant 1 =====
#
# Not interleaved: 3
# Interleaved with one: 48
# Interleaved with two or more: 1443
#
#
#
# ===== Start Iteration 16 with variant 2 =====
#
# Not interleaved: 8
# Interleaved with one: 76
# Interleaved with two or more: 1410
#
#
#
# ===== Start Iteration 16 with variant 3 =====
#
# Not interleaved: 5
# Interleaved with one: 102
# Interleaved with two or more: 1387
#
#
#
# ===== Start Iteration 16 with variant 4 =====
#
# Not interleaved: 1
# Interleaved with one: 36
# Interleaved with two or more: 1457
#
#
#
# ===== Start Iteration 16 with variant 5 =====
#
# Not interleaved: 2
# Interleaved with one: 28
# Interleaved with two or more: 1464
#
# ===== Start Iteration 17 =====
#
#
# ===== Start Iteration 17 with variant 1 =====
#
# Not interleaved: 12
# Interleaved with one: 161
# Interleaved with two or more: 721
#
#
#
# ===== Start Iteration 17 with variant 2 =====
#
# Not interleaved: 19
# Interleaved with one: 168
# Interleaved with two or more: 707
#
#
#
# ===== Start Iteration 17 with variant 3 =====
#
# Not interleaved: 19
# Interleaved with one: 150
# Interleaved with two or more: 725
#
#
#
# ===== Start Iteration 17 with variant 4 =====
#
# Not interleaved: 24
# Interleaved with one: 85
# Interleaved with two or more: 785
#
#
#
# ===== Start Iteration 17 with variant 5 =====
#
# Not interleaved: 14
# Interleaved with one: 121
# Interleaved with two or more: 759
#
# ===== Start Iteration 18 =====
#
#
# ===== Start Iteration 18 with variant 1 =====
#
# Not interleaved: 60
# Interleaved with one: 366
# Interleaved with two or more: 330
#
#
#
# ===== Start Iteration 18 with variant 2 =====
#
# Not interleaved: 60
# Interleaved with one: 364
# Interleaved with two or more: 332
#
#
#
# ===== Start Iteration 18 with variant 3 =====
#
# Not interleaved: 58
# Interleaved with one: 367
# Interleaved with two or more: 331
#
#
#
# ===== Start Iteration 18 with variant 4 =====
#
# Not interleaved: 58
# Interleaved with one: 365
# Interleaved with two or more: 333
#
#
#
# ===== Start Iteration 18 with variant 5 =====
#
# Not interleaved: 56
# Interleaved with one: 369
# Interleaved with two or more: 331
#
# ===== Start Iteration 19 =====
#
#
# ===== Start Iteration 19 with variant 1 =====
#
# Not interleaved: 2
# Interleaved with one: 481
# Interleaved with two or more: 913
#
#
#
# ===== Start Iteration 19 with variant 2 =====
#
# Not interleaved: 16
# Interleaved with one: 305
# Interleaved with two or more: 1075
#
#
#
# ===== Start Iteration 19 with variant 3 =====
#
# Not interleaved: 17
# Interleaved with one: 837
# Interleaved with two or more: 542
#
#
#
# ===== Start Iteration 19 with variant 4 =====
#
# Not interleaved: 0
# Interleaved with one: 573
# Interleaved with two or more: 823
#
#
#
# ===== Start Iteration 19 with variant 5 =====
#
# Not interleaved: 5
# Interleaved with one: 453
# Interleaved with two or more: 938
#
# ===== Start Iteration 20 =====
#
#
# ===== Start Iteration 20 with variant 1 =====
#
# Not interleaved: 22
# Interleaved with one: 444
# Interleaved with two or more: 679
#
#
#
# ===== Start Iteration 20 with variant 2 =====
#
# Not interleaved: 5
# Interleaved with one: 346
# Interleaved with two or more: 794
#
#
#
# ===== Start Iteration 20 with variant 3 =====
#
# Not interleaved: 23
# Interleaved with one: 293
# Interleaved with two or more: 829
#
#
#
# ===== Start Iteration 20 with variant 4 =====
#
# Not interleaved: 27
# Interleaved with one: 205
# Interleaved with two or more: 913
#
#
#
# ===== Start Iteration 20 with variant 5 =====
#
# Not interleaved: 70
# Interleaved with one: 499
# Interleaved with two or more: 576
#
# ===== Start Iteration 21 =====
#
#
# ===== Start Iteration 21 with variant 1 =====
#
# Not interleaved: 33
# Interleaved with one: 123
# Interleaved with two or more: 811
#
#
#
# ===== Start Iteration 21 with variant 2 =====
#
# Not interleaved: 20
# Interleaved with one: 243
# Interleaved with two or more: 704
#
#
#
# ===== Start Iteration 21 with variant 3 =====
#
# Not interleaved: 22
# Interleaved with one: 425
# Interleaved with two or more: 520
#
#
#
# ===== Start Iteration 21 with variant 4 =====
#
# Not interleaved: 42
# Interleaved with one: 74
# Interleaved with two or more: 851
#
#
#
# ===== Start Iteration 21 with variant 5 =====
#
# Not interleaved: 22
# Interleaved with one: 315
# Interleaved with two or more: 630
#
# ===== Start Iteration 22 =====
#
#
# ===== Start Iteration 22 with variant 1 =====
#
# Not interleaved: 58
# Interleaved with one: 368
# Interleaved with two or more: 330
#
#
#
# ===== Start Iteration 22 with variant 2 =====
#
# Not interleaved: 60
# Interleaved with one: 363
# Interleaved with two or more: 333
#
#
#
# ===== Start Iteration 22 with variant 3 =====
#
# Not interleaved: 59
# Interleaved with one: 366
# Interleaved with two or more: 331
#
#
#
# ===== Start Iteration 22 with variant 4 =====
#
# Not interleaved: 58
# Interleaved with one: 367
# Interleaved with two or more: 331
#
#
#
# ===== Start Iteration 22 with variant 5 =====
#
# Not interleaved: 58
# Interleaved with one: 365
# Interleaved with two or more: 333
#
# ===== Start Iteration 23 =====
#
#
# ===== Start Iteration 23 with variant 1 =====
#
# Not interleaved: 55
# Interleaved with one: 296
# Interleaved with two or more: 943
#
#
#
# ===== Start Iteration 23 with variant 2 =====
#
# Not interleaved: 42
# Interleaved with one: 169
# Interleaved with two or more: 1083
#
#
#
# ===== Start Iteration 23 with variant 3 =====
#
# Not interleaved: 22
# Interleaved with one: 187
# Interleaved with two or more: 1085
#
#
#
# ===== Start Iteration 23 with variant 4 =====
#
# Not interleaved: 12
# Interleaved with one: 77
# Interleaved with two or more: 1205
#
#
#
# ===== Start Iteration 23 with variant 5 =====
#
# Not interleaved: 37
# Interleaved with one: 231
# Interleaved with two or more: 1026
#
# ===== Start Iteration 24 =====
#
#
# ===== Start Iteration 24 with variant 1 =====
#
# Not interleaved: 0
# Interleaved with one: 125
# Interleaved with two or more: 1316
#
#
#
# ===== Start Iteration 24 with variant 2 =====
#
# Not interleaved: 3
# Interleaved with one: 79
# Interleaved with two or more: 1359
#
#
#
# ===== Start Iteration 24 with variant 3 =====
#
# Not interleaved: 8
# Interleaved with one: 103
# Interleaved with two or more: 1330
#
#
#
# ===== Start Iteration 24 with variant 4 =====
#
# Not interleaved: 4
# Interleaved with one: 72
# Interleaved with two or more: 1365
#
#
#
# ===== Start Iteration 24 with variant 5 =====
#
# Not interleaved: 0
# Interleaved with one: 126
# Interleaved with two or more: 1315
#
# ===== Start Iteration 25 =====
#
#
# ===== Start Iteration 25 with variant 1 =====
#
# Not interleaved: 6
# Interleaved with one: 192
# Interleaved with two or more: 1388
#
#
#
# ===== Start Iteration 25 with variant 2 =====
#
# Not interleaved: 5
# Interleaved with one: 156
# Interleaved with two or more: 1425
#
#
#
# ===== Start Iteration 25 with variant 3 =====
#
# Not interleaved: 1
# Interleaved with one: 180
# Interleaved with two or more: 1405
#
#
#
# ===== Start Iteration 25 with variant 4 =====
#
# Not interleaved: 6
# Interleaved with one: 217
# Interleaved with two or more: 1363
#
#
#
# ===== Start Iteration 25 with variant 5 =====
#
# Not interleaved: 6
# Interleaved with one: 56
# Interleaved with two or more: 1524
#
# ===== Start Iteration 26 =====
#
#
# ===== Start Iteration 26 with variant 1 =====
#
# Not interleaved: 7
# Interleaved with one: 165
# Interleaved with two or more: 1343
#
#
#
# ===== Start Iteration 26 with variant 2 =====
#
# Not interleaved: 5
# Interleaved with one: 44
# Interleaved with two or more: 1466
#
#
#
# ===== Start Iteration 26 with variant 3 =====
#
# Not interleaved: 5
# Interleaved with one: 225
# Interleaved with two or more: 1285
#
#
#
# ===== Start Iteration 26 with variant 4 =====
#
# Not interleaved: 3
# Interleaved with one: 249
# Interleaved with two or more: 1263
#
#
#
# ===== Start Iteration 26 with variant 5 =====
#
# Not interleaved: 4
# Interleaved with one: 139
# Interleaved with two or more: 1372
#
# ===== Start Iteration 27 =====
#
#
# ===== Start Iteration 27 with variant 1 =====
#
# Not interleaved: 13
# Interleaved with one: 114
# Interleaved with two or more: 1446
#
#
#
# ===== Start Iteration 27 with variant 2 =====
#
# Not interleaved: 4
# Interleaved with one: 76
# Interleaved with two or more: 1493
#
#
#
# ===== Start Iteration 27 with variant 3 =====
#
# Not interleaved: 13
# Interleaved with one: 144
# Interleaved with two or more: 1416
#
#
#
# ===== Start Iteration 27 with variant 4 =====
#
# Not interleaved: 6
# Interleaved with one: 138
# Interleaved with two or more: 1429
#
#
#
# ===== Start Iteration 27 with variant 5 =====
#
# Not interleaved: 7
# Interleaved with one: 97
# Interleaved with two or more: 1469
#
# ===== Start Iteration 28 =====
#
#
# ===== Start Iteration 28 with variant 1 =====
#
# Not interleaved: 23
# Interleaved with one: 130
# Interleaved with two or more: 855
#
#
#
# ===== Start Iteration 28 with variant 2 =====
#
# Not interleaved: 30
# Interleaved with one: 157
# Interleaved with two or more: 821
#
#
#
# ===== Start Iteration 28 with variant 3 =====
#
# Not interleaved: 5
# Interleaved with one: 53
# Interleaved with two or more: 950
#
#
#
# ===== Start Iteration 28 with variant 4 =====
#
# Not interleaved: 28
# Interleaved with one: 182
# Interleaved with two or more: 798
#
#
#
# ===== Start Iteration 28 with variant 5 =====
#
# Not interleaved: 11
# Interleaved with one: 210
# Interleaved with two or more: 787
#
# ===== Start Iteration 29 =====
#
#
# ===== Start Iteration 29 with variant 1 =====
#
# Not interleaved: 11
# Interleaved with one: 84
# Interleaved with two or more: 398
#
#
#
# ===== Start Iteration 29 with variant 2 =====
#
# Not interleaved: 18
# Interleaved with one: 175
# Interleaved with two or more: 300
#
#
#
# ===== Start Iteration 29 with variant 3 =====
#
# Not interleaved: 30
# Interleaved with one: 166
# Interleaved with two or more: 297
#
#
#
# ===== Start Iteration 29 with variant 4 =====
#
# Not interleaved: 44
# Interleaved with one: 200
# Interleaved with two or more: 249
#
#
#
# ===== Start Iteration 29 with variant 5 =====
#
# Not interleaved: 21
# Interleaved with one: 261
# Interleaved with two or more: 211
#
# ===== Start Iteration 30 =====
#
#
# ===== Start Iteration 30 with variant 1 =====
#
# Not interleaved: 95
# Interleaved with one: 443
# Interleaved with two or more: 328
#
#
#
# ===== Start Iteration 30 with variant 2 =====
#
# Not interleaved: 96
# Interleaved with one: 443
# Interleaved with two or more: 327
#
#
#
# ===== Start Iteration 30 with variant 3 =====
#
# Not interleaved: 95
# Interleaved with one: 445
# Interleaved with two or more: 326
#
#
#
# ===== Start Iteration 30 with variant 4 =====
#
# Not interleaved: 97
# Interleaved with one: 442
# Interleaved with two or more: 327
#
#
#
# ===== Start Iteration 30 with variant 5 =====
#
# Not interleaved: 95
# Interleaved with one: 443
# Interleaved with two or more: 328
#
# ===== Start Iteration 31 =====
#
#
# ===== Start Iteration 31 with variant 1 =====
#
# Not interleaved: 82
# Interleaved with one: 549
# Interleaved with two or more: 368
#
#
#
# ===== Start Iteration 31 with variant 2 =====
#
# Not interleaved: 79
# Interleaved with one: 549
# Interleaved with two or more: 371
#
#
#
# ===== Start Iteration 31 with variant 3 =====
#
# Not interleaved: 80
# Interleaved with one: 550
# Interleaved with two or more: 369
#
#
#
# ===== Start Iteration 31 with variant 4 =====
#
# Not interleaved: 82
# Interleaved with one: 550
# Interleaved with two or more: 367
#
#
#
# ===== Start Iteration 31 with variant 5 =====
#
# Not interleaved: 83
# Interleaved with one: 548
# Interleaved with two or more: 368
#
# ===== Start Iteration 32 =====
#
#
# ===== Start Iteration 32 with variant 1 =====
#
# Not interleaved: 421
# Interleaved with one: 636
# Interleaved with two or more: 338
#
#
#
# ===== Start Iteration 32 with variant 2 =====
#
# Not interleaved: 422
# Interleaved with one: 637
# Interleaved with two or more: 336
#
#
#
# ===== Start Iteration 32 with variant 3 =====
#
# Not interleaved: 423
# Interleaved with one: 634
# Interleaved with two or more: 338
#
#
#
# ===== Start Iteration 32 with variant 4 =====
#
# Not interleaved: 421
# Interleaved with one: 638
# Interleaved with two or more: 336
#
#
#
# ===== Start Iteration 32 with variant 5 =====
#
# Not interleaved: 423
# Interleaved with one: 636
# Interleaved with two or more: 336
#
# ===== Start Iteration 33 =====
#
#
# ===== Start Iteration 33 with variant 1 =====
#
# Not interleaved: 19
# Interleaved with one: 76
# Interleaved with two or more: 1461
#
#
#
# ===== Start Iteration 33 with variant 2 =====
#
# Not interleaved: 13
# Interleaved with one: 239
# Interleaved with two or more: 1304
#
#
#
# ===== Start Iteration 33 with variant 3 =====
#
# Not interleaved: 3
# Interleaved with one: 75
# Interleaved with two or more: 1478
#
#
#
# ===== Start Iteration 33 with variant 4 =====
#
# Not interleaved: 2
# Interleaved with one: 186
# Interleaved with two or more: 1368
#
#
#
# ===== Start Iteration 33 with variant 5 =====
#
# Not interleaved: 0
# Interleaved with one: 64
# Interleaved with two or more: 1492
#
# ===== Start Iteration 34 =====
#
#
# ===== Start Iteration 34 with variant 1 =====
#
# Not interleaved: 16
# Interleaved with one: 248
# Interleaved with two or more: 870
#
#
#
# ===== Start Iteration 34 with variant 2 =====
#
# Not interleaved: 3
# Interleaved with one: 260
# Interleaved with two or more: 871
#
#
#
# ===== Start Iteration 34 with variant 3 =====
#
# Not interleaved: 22
# Interleaved with one: 154
# Interleaved with two or more: 958
#
#
#
# ===== Start Iteration 34 with variant 4 =====
#
# Not interleaved: 2
# Interleaved with one: 70
# Interleaved with two or more: 1062
#
#
#
# ===== Start Iteration 34 with variant 5 =====
#
# Not interleaved: 2
# Interleaved with one: 206
# Interleaved with two or more: 926
#
# ===== Start Iteration 35 =====
#
#
# ===== Start Iteration 35 with variant 1 =====
#
# Not interleaved: 11
# Interleaved with one: 173
# Interleaved with two or more: 971
#
#
#
# ===== Start Iteration 35 with variant 2 =====
#
# Not interleaved: 6
# Interleaved with one: 106
# Interleaved with two or more: 1043
#
#
#
# ===== Start Iteration 35 with variant 3 =====
#
# Not interleaved: 10
# Interleaved with one: 107
# Interleaved with two or more: 1038
#
#
#
# ===== Start Iteration 35 with variant 4 =====
#
# Not interleaved: 10
# Interleaved with one: 139
# Interleaved with two or more: 1006
#
#
#
# ===== Start Iteration 35 with variant 5 =====
#
# Not interleaved: 12
# Interleaved with one: 67
# Interleaved with two or more: 1076
#
# ===== Start Iteration 36 =====
#
#
# ===== Start Iteration 36 with variant 1 =====
#
# Not interleaved: 40
# Interleaved with one: 134
# Interleaved with two or more: 226
#
#
#
# ===== Start Iteration 36 with variant 2 =====
#
# Not interleaved: 34
# Interleaved with one: 128
# Interleaved with two or more: 238
#
#
#
# ===== Start Iteration 36 with variant 3 =====
#
# Not interleaved: 35
# Interleaved with one: 174
# Interleaved with two or more: 191
#
#
#
# ===== Start Iteration 36 with variant 4 =====
#
# Not interleaved: 55
# Interleaved with one: 133
# Interleaved with two or more: 212
#
#
#
# ===== Start Iteration 36 with variant 5 =====
#
# Not interleaved: 71
# Interleaved with one: 156
# Interleaved with two or more: 173
#
# ===== Start Iteration 37 =====
#
#
# ===== Start Iteration 37 with variant 1 =====
#
# Not interleaved: 48
# Interleaved with one: 274
# Interleaved with two or more: 678
#
#
#
# ===== Start Iteration 37 with variant 2 =====
#
# Not interleaved: 46
# Interleaved with one: 331
# Interleaved with two or more: 623
#
#
#
# ===== Start Iteration 37 with variant 3 =====
#
# Not interleaved: 24
# Interleaved with one: 284
# Interleaved with two or more: 692
#
#
#
# ===== Start Iteration 37 with variant 4 =====
#
# Not interleaved: 15
# Interleaved with one: 568
# Interleaved with two or more: 417
#
#
#
# ===== Start Iteration 37 with variant 5 =====
#
# Not interleaved: 19
# Interleaved with one: 647
# Interleaved with two or more: 334
#
# ===== Start Iteration 38 =====
#
#
# ===== Start Iteration 38 with variant 1 =====
#
# Not interleaved: 132
# Interleaved with one: 219
# Interleaved with two or more: 312
#
#
#
# ===== Start Iteration 38 with variant 2 =====
#
# Not interleaved: 134
# Interleaved with one: 217
# Interleaved with two or more: 312
#
#
#
# ===== Start Iteration 38 with variant 3 =====
#
# Not interleaved: 130
# Interleaved with one: 223
# Interleaved with two or more: 310
#
#
#
# ===== Start Iteration 38 with variant 4 =====
#
# Not interleaved: 130
# Interleaved with one: 222
# Interleaved with two or more: 311
#
#
#
# ===== Start Iteration 38 with variant 5 =====
#
# Not interleaved: 130
# Interleaved with one: 221
# Interleaved with two or more: 312
#
# ===== Start Iteration 39 =====
#
#
# ===== Start Iteration 39 with variant 1 =====
#
# Not interleaved: 45
# Interleaved with one: 506
# Interleaved with two or more: 253
#
#
#
# ===== Start Iteration 39 with variant 2 =====
#
# Not interleaved: 33
# Interleaved with one: 272
# Interleaved with two or more: 499
#
#
#
# ===== Start Iteration 39 with variant 3 =====
#
# Not interleaved: 31
# Interleaved with one: 270
# Interleaved with two or more: 503
#
#
#
# ===== Start Iteration 39 with variant 4 =====
#
# Not interleaved: 67
# Interleaved with one: 430
# Interleaved with two or more: 307
#
#
#
# ===== Start Iteration 39 with variant 5 =====
#
# Not interleaved: 6
# Interleaved with one: 163
# Interleaved with two or more: 635
#
# ===== Start Iteration 40 =====
#
#
# ===== Start Iteration 40 with variant 1 =====
#
# Not interleaved: 30
# Interleaved with one: 105
# Interleaved with two or more: 846
#
#
#
# ===== Start Iteration 40 with variant 2 =====
#
# Not interleaved: 22
# Interleaved with one: 41
# Interleaved with two or more: 918
#
#
#
# ===== Start Iteration 40 with variant 3 =====
#
# Not interleaved: 43
# Interleaved with one: 131
# Interleaved with two or more: 807
#
#
#
# ===== Start Iteration 40 with variant 4 =====
#
# Not interleaved: 38
# Interleaved with one: 274
# Interleaved with two or more: 669
#
#
#
# ===== Start Iteration 40 with variant 5 =====
#
# Not interleaved: 17
# Interleaved with one: 50
# Interleaved with two or more: 914
#
# ===== Start Iteration 41 =====
#
#
# ===== Start Iteration 41 with variant 1 =====
#
# Not interleaved: 43
# Interleaved with one: 299
# Interleaved with two or more: 925
#
#
#
# ===== Start Iteration 41 with variant 2 =====
#
# Not interleaved: 17
# Interleaved with one: 174
# Interleaved with two or more: 1076
#
#
#
# ===== Start Iteration 41 with variant 3 =====
#
# Not interleaved: 10
# Interleaved with one: 182
# Interleaved with two or more: 1075
#
#
#
# ===== Start Iteration 41 with variant 4 =====
#
# Not interleaved: 57
# Interleaved with one: 539
# Interleaved with two or more: 671
#
#
#
# ===== Start Iteration 41 with variant 5 =====
#
# Not interleaved: 19
# Interleaved with one: 310
# Interleaved with two or more: 938
#
# ===== Start Iteration 42 =====
#
#
# ===== Start Iteration 42 with variant 1 =====
#
# Not interleaved: 9
# Interleaved with one: 308
# Interleaved with two or more: 1071
#
#
#
# ===== Start Iteration 42 with variant 2 =====
#
# Not interleaved: 5
# Interleaved with one: 295
# Interleaved with two or more: 1088
#
#
#
# ===== Start Iteration 42 with variant 3 =====
#
# Not interleaved: 15
# Interleaved with one: 632
# Interleaved with two or more: 741
#
#
#
# ===== Start Iteration 42 with variant 4 =====
#
# Not interleaved: 19
# Interleaved with one: 640
# Interleaved with two or more: 729
#
#
#
# ===== Start Iteration 42 with variant 5 =====
#
# Not interleaved: 3
# Interleaved with one: 281
# Interleaved with two or more: 1104
#
# ===== Start Iteration 43 =====
#
#
# ===== Start Iteration 43 with variant 1 =====
#
# Not interleaved: 15
# Interleaved with one: 107
# Interleaved with two or more: 908
#
#
#
# ===== Start Iteration 43 with variant 2 =====
#
# Not interleaved: 11
# Interleaved with one: 45
# Interleaved with two or more: 974
#
#
#
# ===== Start Iteration 43 with variant 3 =====
#
# Not interleaved: 6
# Interleaved with one: 83
# Interleaved with two or more: 941
#
#
#
# ===== Start Iteration 43 with variant 4 =====
#
# Not interleaved: 13
# Interleaved with one: 97
# Interleaved with two or more: 920
#
#
#
# ===== Start Iteration 43 with variant 5 =====
#
# Not interleaved: 24
# Interleaved with one: 213
# Interleaved with two or more: 793
#
# ===== Start Iteration 44 =====
#
#
# ===== Start Iteration 44 with variant 1 =====
#
# Not interleaved: 8
# Interleaved with one: 73
# Interleaved with two or more: 975
#
#
#
# ===== Start Iteration 44 with variant 2 =====
#
# Not interleaved: 19
# Interleaved with one: 202
# Interleaved with two or more: 835
#
#
#
# ===== Start Iteration 44 with variant 3 =====
#
# Not interleaved: 25
# Interleaved with one: 91
# Interleaved with two or more: 940
#
#
#
# ===== Start Iteration 44 with variant 4 =====
#
# Not interleaved: 40
# Interleaved with one: 138
# Interleaved with two or more: 878
#
#
#
# ===== Start Iteration 44 with variant 5 =====
#
# Not interleaved: 38
# Interleaved with one: 170
# Interleaved with two or more: 848
#
# ===== Start Iteration 45 =====
#
#
# ===== Start Iteration 45 with variant 1 =====
#
# Not interleaved: 23
# Interleaved with one: 224
# Interleaved with two or more: 667
#
#
#
# ===== Start Iteration 45 with variant 2 =====
#
# Not interleaved: 42
# Interleaved with one: 138
# Interleaved with two or more: 734
#
#
#
# ===== Start Iteration 45 with variant 3 =====
#
# Not interleaved: 31
# Interleaved with one: 359
# Interleaved with two or more: 524
#
#
#
# ===== Start Iteration 45 with variant 4 =====
#
# Not interleaved: 58
# Interleaved with one: 212
# Interleaved with two or more: 644
#
#
#
# ===== Start Iteration 45 with variant 5 =====
#
# Not interleaved: 26
# Interleaved with one: 346
# Interleaved with two or more: 542
#
# ===== Start Iteration 46 =====
#
#
# ===== Start Iteration 46 with variant 1 =====
#
# Not interleaved: 11
# Interleaved with one: 362
# Interleaved with two or more: 454
#
#
#
# ===== Start Iteration 46 with variant 2 =====
#
# Not interleaved: 43
# Interleaved with one: 194
# Interleaved with two or more: 590
#
#
#
# ===== Start Iteration 46 with variant 3 =====
#
# Not interleaved: 48
# Interleaved with one: 77
# Interleaved with two or more: 702
#
#
#
# ===== Start Iteration 46 with variant 4 =====
#
# Not interleaved: 43
# Interleaved with one: 125
# Interleaved with two or more: 659
#
#
#
# ===== Start Iteration 46 with variant 5 =====
#
# Not interleaved: 75
# Interleaved with one: 370
# Interleaved with two or more: 382
#
# ===== Start Iteration 47 =====
#
#
# ===== Start Iteration 47 with variant 1 =====
#
# Not interleaved: 133
# Interleaved with one: 334
# Interleaved with two or more: 270
#
#
#
# ===== Start Iteration 47 with variant 2 =====
#
# Not interleaved: 131
# Interleaved with one: 336
# Interleaved with two or more: 270
#
#
#
# ===== Start Iteration 47 with variant 3 =====
#
# Not interleaved: 133
# Interleaved with one: 335
# Interleaved with two or more: 269
#
#
#
# ===== Start Iteration 47 with variant 4 =====
#
# Not interleaved: 131
# Interleaved with one: 337
# Interleaved with two or more: 269
#
#
#
# ===== Start Iteration 47 with variant 5 =====
#
# Not interleaved: 130
# Interleaved with one: 337
# Interleaved with two or more: 270
#
# ===== Start Iteration 48 =====
#
#
# ===== Start Iteration 48 with variant 1 =====
#
# Not interleaved: 142
# Interleaved with one: 517
# Interleaved with two or more: 353
#
#
#
# ===== Start Iteration 48 with variant 2 =====
#
# Not interleaved: 141
# Interleaved with one: 519
# Interleaved with two or more: 352
#
#
#
# ===== Start Iteration 48 with variant 3 =====
#
# Not interleaved: 137
# Interleaved with one: 523
# Interleaved with two or more: 352
#
#
#
# ===== Start Iteration 48 with variant 4 =====
#
# Not interleaved: 141
# Interleaved with one: 518
# Interleaved with two or more: 353
#
#
#
# ===== Start Iteration 48 with variant 5 =====
#
# Not interleaved: 138
# Interleaved with one: 522
# Interleaved with two or more: 352
#
# ===== Start Iteration 49 =====
#
#
# ===== Start Iteration 49 with variant 1 =====
#
# Not interleaved: 75
# Interleaved with one: 279
# Interleaved with two or more: 166
#
#
#
# ===== Start Iteration 49 with variant 2 =====
#
# Not interleaved: 9
# Interleaved with one: 116
# Interleaved with two or more: 395
#
#
#
# ===== Start Iteration 49 with variant 3 =====
#
# Not interleaved: 57
# Interleaved with one: 225
# Interleaved with two or more: 238
#
#
#
# ===== Start Iteration 49 with variant 4 =====
#
# Not interleaved: 6
# Interleaved with one: 248
# Interleaved with two or more: 266
#
#
#
# ===== Start Iteration 49 with variant 5 =====
#
# Not interleaved: 5
# Interleaved with one: 140
# Interleaved with two or more: 375
#
# ===== Start Iteration 50 =====
#
#
# ===== Start Iteration 50 with variant 1 =====
#
# Not interleaved: 30
# Interleaved with one: 100
# Interleaved with two or more: 624
#
#
#
# ===== Start Iteration 50 with variant 2 =====
#
# Not interleaved: 24
# Interleaved with one: 223
# Interleaved with two or more: 507
#
#
#
# ===== Start Iteration 50 with variant 3 =====
#
# Not interleaved: 35
# Interleaved with one: 169
# Interleaved with two or more: 550
#
#
#
# ===== Start Iteration 50 with variant 4 =====
#
# Not interleaved: 14
# Interleaved with one: 145
# Interleaved with two or more: 595
#
#
#
# ===== Start Iteration 50 with variant 5 =====
#
# Not interleaved: 59
# Interleaved with one: 133
# Interleaved with two or more: 562
#
# ===== Start Iteration 51 =====
#
#
# ===== Start Iteration 51 with variant 1 =====
#
# Not interleaved: 15
# Interleaved with one: 71
# Interleaved with two or more: 595
#
#
#
# ===== Start Iteration 51 with variant 2 =====
#
# Not interleaved: 11
# Interleaved with one: 85
# Interleaved with two or more: 585
#
#
#
# ===== Start Iteration 51 with variant 3 =====
#
# Not interleaved: 22
# Interleaved with one: 140
# Interleaved with two or more: 519
#
#
#
# ===== Start Iteration 51 with variant 4 =====
#
# Not interleaved: 20
# Interleaved with one: 82
# Interleaved with two or more: 579
#
#
#
# ===== Start Iteration 51 with variant 5 =====
#
# Not interleaved: 9
# Interleaved with one: 174
# Interleaved with two or more: 498
#
# ===== Start Iteration 52 =====
#
#
# ===== Start Iteration 52 with variant 1 =====
#
# Not interleaved: 28
# Interleaved with one: 250
# Interleaved with two or more: 651
#
#
#
# ===== Start Iteration 52 with variant 2 =====
#
# Not interleaved: 22
# Interleaved with one: 242
# Interleaved with two or more: 665
#
#
#
# ===== Start Iteration 52 with variant 3 =====
#
# Not interleaved: 0
# Interleaved with one: 208
# Interleaved with two or more: 721
#
#
#
# ===== Start Iteration 52 with variant 4 =====
#
# Not interleaved: 12
# Interleaved with one: 48
# Interleaved with two or more: 869
#
#
#
# ===== Start Iteration 52 with variant 5 =====
#
# Not interleaved: 4
# Interleaved with one: 226
# Interleaved with two or more: 699
#
# ===== Start Iteration 53 =====
#
#
# ===== Start Iteration 53 with variant 1 =====
#
# Not interleaved: 5
# Interleaved with one: 162
# Interleaved with two or more: 967
#
#
#
# ===== Start Iteration 53 with variant 2 =====
#
# Not interleaved: 4
# Interleaved with one: 247
# Interleaved with two or more: 883
#
#
#
# ===== Start Iteration 53 with variant 3 =====
#
# Not interleaved: 14
# Interleaved with one: 247
# Interleaved with two or more: 873
#
#
#
# ===== Start Iteration 53 with variant 4 =====
#
# Not interleaved: 7
# Interleaved with one: 163
# Interleaved with two or more: 964
#
#
#
# ===== Start Iteration 53 with variant 5 =====
#
# Not interleaved: 2
# Interleaved with one: 97
# Interleaved with two or more: 1035
#
# ===== Start Iteration 54 =====
#
#
# ===== Start Iteration 54 with variant 1 =====
#
# Not interleaved: 22
# Interleaved with one: 165
# Interleaved with two or more: 510
#
#
#
# ===== Start Iteration 54 with variant 2 =====
#
# Not interleaved: 8
# Interleaved with one: 226
# Interleaved with two or more: 463
#
#
#
# ===== Start Iteration 54 with variant 3 =====
#
# Not interleaved: 29
# Interleaved with one: 84
# Interleaved with two or more: 584
#
#
#
# ===== Start Iteration 54 with variant 4 =====
#
# Not interleaved: 32
# Interleaved with one: 78
# Interleaved with two or more: 587
#
#
#
# ===== Start Iteration 54 with variant 5 =====
#
# Not interleaved: 10
# Interleaved with one: 111
# Interleaved with two or more: 576
#
# ===== Start Iteration 55 =====
#
#
# ===== Start Iteration 55 with variant 1 =====
#
# Not interleaved: 1
# Interleaved with one: 114
# Interleaved with two or more: 1283
#
#
#
# ===== Start Iteration 55 with variant 2 =====
#
# Not interleaved: 2
# Interleaved with one: 23
# Interleaved with two or more: 1373
#
#
#
# ===== Start Iteration 55 with variant 3 =====
#
# Not interleaved: 5
# Interleaved with one: 50
# Interleaved with two or more: 1343
#
#
#
# ===== Start Iteration 55 with variant 4 =====
#
# Not interleaved: 2
# Interleaved with one: 21
# Interleaved with two or more: 1375
#
#
#
# ===== Start Iteration 55 with variant 5 =====
#
# Not interleaved: 8
# Interleaved with one: 110
# Interleaved with two or more: 1280
#
# ===== Start Iteration 56 =====
#
#
# ===== Start Iteration 56 with variant 1 =====
#
# Not interleaved: 157
# Interleaved with one: 259
# Interleaved with two or more: 258
#
#
#
# ===== Start Iteration 56 with variant 2 =====
#
# Not interleaved: 157
# Interleaved with one: 261
# Interleaved with two or more: 256
#
#
#
# ===== Start Iteration 56 with variant 3 =====
#
# Not interleaved: 153
# Interleaved with one: 264
# Interleaved with two or more: 257
#
#
#
# ===== Start Iteration 56 with variant 4 =====
#
# Not interleaved: 157
# Interleaved with one: 259
# Interleaved with two or more: 258
#
#
#
# ===== Start Iteration 56 with variant 5 =====
#
# Not interleaved: 158
# Interleaved with one: 258
# Interleaved with two or more: 258
#
# ===== Start Iteration 57 =====
#
#
# ===== Start Iteration 57 with variant 1 =====
#
# Not interleaved: 33
# Interleaved with one: 0
# Interleaved with two or more: 312
#
#
#
# ===== Start Iteration 57 with variant 2 =====
#
# Not interleaved: 33
# Interleaved with one: 0
# Interleaved with two or more: 312
#
#
#
# ===== Start Iteration 57 with variant 3 =====
#
# Not interleaved: 33
# Interleaved with one: 0
# Interleaved with two or more: 312
#
#
#
# ===== Start Iteration 57 with variant 4 =====
#
# Not interleaved: 34
# Interleaved with one: 0
# Interleaved with two or more: 311
#
#
#
# ===== Start Iteration 57 with variant 5 =====
#
# Not interleaved: 34
# Interleaved with one: 0
# Interleaved with two or more: 311
#
# ===== Start Iteration 58 =====
#
#
# ===== Start Iteration 58 with variant 1 =====
#
# Not interleaved: 16
# Interleaved with one: 131
# Interleaved with two or more: 1096
#
#
#
# ===== Start Iteration 58 with variant 2 =====
#
# Not interleaved: 29
# Interleaved with one: 207
# Interleaved with two or more: 1007
#
#
#
# ===== Start Iteration 58 with variant 3 =====
#
# Not interleaved: 6
# Interleaved with one: 53
# Interleaved with two or more: 1184
#
#
#
# ===== Start Iteration 58 with variant 4 =====
#
# Not interleaved: 12
# Interleaved with one: 59
# Interleaved with two or more: 1172
#
#
#
# ===== Start Iteration 58 with variant 5 =====
#
# Not interleaved: 10
# Interleaved with one: 135
# Interleaved with two or more: 1098
#
# ===== Start Iteration 59 =====
#
#
# ===== Start Iteration 59 with variant 1 =====
#
# Not interleaved: 33
# Interleaved with one: 124
# Interleaved with two or more: 891
#
#
#
# ===== Start Iteration 59 with variant 2 =====
#
# Not interleaved: 8
# Interleaved with one: 110
# Interleaved with two or more: 930
#
#
#
# ===== Start Iteration 59 with variant 3 =====
#
# Not interleaved: 10
# Interleaved with one: 78
# Interleaved with two or more: 960
#
#
#
# ===== Start Iteration 59 with variant 4 =====
#
# Not interleaved: 26
# Interleaved with one: 147
# Interleaved with two or more: 875
#
#
#
# ===== Start Iteration 59 with variant 5 =====
#
# Not interleaved: 10
# Interleaved with one: 108
# Interleaved with two or more: 930
#
# ===== Start Iteration 60 =====
#
#
# ===== Start Iteration 60 with variant 1 =====
#
# Not interleaved: 41
# Interleaved with one: 388
# Interleaved with two or more: 884
#
#
#
# ===== Start Iteration 60 with variant 2 =====
#
# Not interleaved: 15
# Interleaved with one: 115
# Interleaved with two or more: 1183
#
#
#
# ===== Start Iteration 60 with variant 3 =====
#
# Not interleaved: 52
# Interleaved with one: 305
# Interleaved with two or more: 956
#
#
#
# ===== Start Iteration 60 with variant 4 =====
#
# Not interleaved: 26
# Interleaved with one: 331
# Interleaved with two or more: 956
#
#
#
# ===== Start Iteration 60 with variant 5 =====
#
# Not interleaved: 21
# Interleaved with one: 205
# Interleaved with two or more: 1087
#
# ===== Start Iteration 61 =====
#
#
# ===== Start Iteration 61 with variant 1 =====
#
# Not interleaved: 31
# Interleaved with one: 195
# Interleaved with two or more: 791
#
#
#
# ===== Start Iteration 61 with variant 2 =====
#
# Not interleaved: 70
# Interleaved with one: 221
# Interleaved with two or more: 726
#
#
#
# ===== Start Iteration 61 with variant 3 =====
#
# Not interleaved: 14
# Interleaved with one: 110
# Interleaved with two or more: 893
#
#
#
# ===== Start Iteration 61 with variant 4 =====
#
# Not interleaved: 35
# Interleaved with one: 46
# Interleaved with two or more: 936
#
#
#
# ===== Start Iteration 61 with variant 5 =====
#
# Not interleaved: 39
# Interleaved with one: 208
# Interleaved with two or more: 770
#
# ===== Start Iteration 62 =====
#
#
# ===== Start Iteration 62 with variant 1 =====
#
# Not interleaved: 1
# Interleaved with one: 268
# Interleaved with two or more: 1022
#
#
#
# ===== Start Iteration 62 with variant 2 =====
#
# Not interleaved: 10
# Interleaved with one: 120
# Interleaved with two or more: 1161
#
#
#
# ===== Start Iteration 62 with variant 3 =====
#
# Not interleaved: 3
# Interleaved with one: 25
# Interleaved with two or more: 1263
#
#
#
# ===== Start Iteration 62 with variant 4 =====
#
# Not interleaved: 29
# Interleaved with one: 117
# Interleaved with two or more: 1145
#
#
#
# ===== Start Iteration 62 with variant 5 =====
#
# Not interleaved: 8
# Interleaved with one: 296
# Interleaved with two or more: 987
#
# ===== Start Iteration 63 =====
#
#
# ===== Start Iteration 63 with variant 1 =====
#
# Not interleaved: 60
# Interleaved with one: 314
# Interleaved with two or more: 803
#
#
#
# ===== Start Iteration 63 with variant 2 =====
#
# Not interleaved: 25
# Interleaved with one: 108
# Interleaved with two or more: 1044
#
#
#
# ===== Start Iteration 63 with variant 3 =====
#
# Not interleaved: 23
# Interleaved with one: 160
# Interleaved with two or more: 994
#
#
#
# ===== Start Iteration 63 with variant 4 =====
#
# Not interleaved: 19
# Interleaved with one: 82
# Interleaved with two or more: 1076
#
#
#
# ===== Start Iteration 63 with variant 5 =====
#
# Not interleaved: 26
# Interleaved with one: 109
# Interleaved with two or more: 1042
#
# ===== Start Iteration 64 =====
#
#
# ===== Start Iteration 64 with variant 1 =====
#
# Not interleaved: 132
# Interleaved with one: 357
# Interleaved with two or more: 314
#
#
#
# ===== Start Iteration 64 with variant 2 =====
#
# Not interleaved: 136
# Interleaved with one: 353
# Interleaved with two or more: 314
#
#
#
# ===== Start Iteration 64 with variant 3 =====
#
# Not interleaved: 135
# Interleaved with one: 352
# Interleaved with two or more: 316
#
#
#
# ===== Start Iteration 64 with variant 4 =====
#
# Not interleaved: 132
# Interleaved with one: 358
# Interleaved with two or more: 313
#
#
#
# ===== Start Iteration 64 with variant 5 =====
#
# Not interleaved: 136
# Interleaved with one: 351
# Interleaved with two or more: 316
#
# ===== Start Iteration 65 =====
#
#
# ===== Start Iteration 65 with variant 1 =====
#
# Not interleaved: 10
# Interleaved with one: 266
# Interleaved with two or more: 1187
#
#
#
# ===== Start Iteration 65 with variant 2 =====
#
# Not interleaved: 2
# Interleaved with one: 318
# Interleaved with two or more: 1143
#
#
#
# ===== Start Iteration 65 with variant 3 =====
#
# Not interleaved: 4
# Interleaved with one: 252
# Interleaved with two or more: 1207
#
#
#
# ===== Start Iteration 65 with variant 4 =====
#
# Not interleaved: 11
# Interleaved with one: 148
# Interleaved with two or more: 1304
#
#
#
# ===== Start Iteration 65 with variant 5 =====
#
# Not interleaved: 11
# Interleaved with one: 539
# Interleaved with two or more: 913
#
# ===== Start Iteration 66 =====
#
#
# ===== Start Iteration 66 with variant 1 =====
#
# Not interleaved: 81
# Interleaved with one: 549
# Interleaved with two or more: 369
#
#
#
# ===== Start Iteration 66 with variant 2 =====
#
# Not interleaved: 82
# Interleaved with one: 547
# Interleaved with two or more: 370
#
#
#
# ===== Start Iteration 66 with variant 3 =====
#
# Not interleaved: 81
# Interleaved with one: 548
# Interleaved with two or more: 370
#
#
#
# ===== Start Iteration 66 with variant 4 =====
#
# Not interleaved: 86
# Interleaved with one: 544
# Interleaved with two or more: 369
#
#
#
# ===== Start Iteration 66 with variant 5 =====
#
# Not interleaved: 85
# Interleaved with one: 543
# Interleaved with two or more: 371
#
# ===== Start Iteration 67 =====
#
#
# ===== Start Iteration 67 with variant 1 =====
#
# Not interleaved: 16
# Interleaved with one: 81
# Interleaved with two or more: 920
#
#
#
# ===== Start Iteration 67 with variant 2 =====
#
# Not interleaved: 56
# Interleaved with one: 104
# Interleaved with two or more: 857
#
#
#
# ===== Start Iteration 67 with variant 3 =====
#
# Not interleaved: 61
# Interleaved with one: 146
# Interleaved with two or more: 810
#
#
#
# ===== Start Iteration 67 with variant 4 =====
#
# Not interleaved: 53
# Interleaved with one: 90
# Interleaved with two or more: 874
#
#
#
# ===== Start Iteration 67 with variant 5 =====
#
# Not interleaved: 18
# Interleaved with one: 95
# Interleaved with two or more: 904
#
# ===== Start Iteration 68 =====
#
#
# ===== Start Iteration 68 with variant 1 =====
#
# Not interleaved: 3
# Interleaved with one: 102
# Interleaved with two or more: 1004
#
#
#
# ===== Start Iteration 68 with variant 2 =====
#
# Not interleaved: 0
# Interleaved with one: 18
# Interleaved with two or more: 1091
#
#
#
# ===== Start Iteration 68 with variant 3 =====
#
# Not interleaved: 0
# Interleaved with one: 128
# Interleaved with two or more: 981
#
#
#
# ===== Start Iteration 68 with variant 4 =====
#
# Not interleaved: 0
# Interleaved with one: 63
# Interleaved with two or more: 1046
#
#
#
# ===== Start Iteration 68 with variant 5 =====
#
# Not interleaved: 1
# Interleaved with one: 65
# Interleaved with two or more: 1043
#
# ===== Start Iteration 69 =====
#
#
# ===== Start Iteration 69 with variant 1 =====
#
# Not interleaved: 22
# Interleaved with one: 150
# Interleaved with two or more: 1411
#
#
#
# ===== Start Iteration 69 with variant 2 =====
#
# Not interleaved: 7
# Interleaved with one: 60
# Interleaved with two or more: 1516
#
#
#
# ===== Start Iteration 69 with variant 3 =====
#
# Not interleaved: 4
# Interleaved with one: 45
# Interleaved with two or more: 1534
#
#
#
# ===== Start Iteration 69 with variant 4 =====
#
# Not interleaved: 12
# Interleaved with one: 114
# Interleaved with two or more: 1457
#
#
#
# ===== Start Iteration 69 with variant 5 =====
#
# Not interleaved: 9
# Interleaved with one: 121
# Interleaved with two or more: 1453
#
# ===== Start Iteration 70 =====
#
#
# ===== Start Iteration 70 with variant 1 =====
#
# Not interleaved: 1
# Interleaved with one: 149
# Interleaved with two or more: 866
#
#
#
# ===== Start Iteration 70 with variant 2 =====
#
# Not interleaved: 7
# Interleaved with one: 179
# Interleaved with two or more: 830
#
#
#
# ===== Start Iteration 70 with variant 3 =====
#
# Not interleaved: 10
# Interleaved with one: 208
# Interleaved with two or more: 798
#
#
#
# ===== Start Iteration 70 with variant 4 =====
#
# Not interleaved: 23
# Interleaved with one: 454
# Interleaved with two or more: 539
#
#
#
# ===== Start Iteration 70 with variant 5 =====
#
# Not interleaved: 4
# Interleaved with one: 74
# Interleaved with two or more: 938
#
# ===== Start Iteration 71 =====
#
#
# ===== Start Iteration 71 with variant 1 =====
#
# Not interleaved: 57
# Interleaved with one: 156
# Interleaved with two or more: 125
#
#
#
# ===== Start Iteration 71 with variant 2 =====
#
# Not interleaved: 66
# Interleaved with one: 102
# Interleaved with two or more: 170
#
#
#
# ===== Start Iteration 71 with variant 3 =====
#
# Not interleaved: 35
# Interleaved with one: 140
# Interleaved with two or more: 163
#
#
#
# ...
#
# Not interleaved: 10
# Interleaved with one: 46
# Interleaved with two or more: 793
#
#
#
# ===== Start Iteration 77 with variant 4 =====
#
# Not interleaved: 19
# Interleaved with one: 115
# Interleaved with two or more: 715
#
#
#
# ===== Start Iteration 77 with variant 5 =====
#
# Not interleaved: 38
# Interleaved with one: 247
# Interleaved with two or more: 564
#
# ===== Start Iteration 78 =====
#
#
# ===== Start Iteration 78 with variant 1 =====
#
# Not interleaved: 49
# Interleaved with one: 246
# Interleaved with two or more: 366
#
#
#
# ===== Start Iteration 78 with variant 2 =====
#
# Not interleaved: 32
# Interleaved with one: 130
# Interleaved with two or more: 499
#
#
#
# ===== Start Iteration 78 with variant 3 =====
#
# Not interleaved: 48
# Interleaved with one: 84
# Interleaved with two or more: 529
#
#
#
# ===== Start Iteration 78 with variant 4 =====
#
# Not interleaved: 13
# Interleaved with one: 128
# Interleaved with two or more: 520
#
#
#
# ===== Start Iteration 78 with variant 5 =====
#
# Not interleaved: 7
# Interleaved with one: 116
# Interleaved with two or more: 538
#
# ===== Start Iteration 79 =====
#
#
# ===== Start Iteration 79 with variant 1 =====
#
# Not interleaved: 66
# Interleaved with one: 202
# Interleaved with two or more: 200
#
#
#
# ===== Start Iteration 79 with variant 2 =====
#
# Not interleaved: 22
# Interleaved with one: 140
# Interleaved with two or more: 306
#
#
#
# ===== Start Iteration 79 with variant 3 =====
#
# Not interleaved: 12
# Interleaved with one: 166
# Interleaved with two or more: 290
#
#
#
# ===== Start Iteration 79 with variant 4 =====
#
# Not interleaved: 29
# Interleaved with one: 97
# Interleaved with two or more: 342
#
#
#
# ===== Start Iteration 79 with variant 5 =====
#
# Not interleaved: 17
# Interleaved with one: 123
# Interleaved with two or more: 328
#
# ===== Start Iteration 80 =====
#
#
# ===== Start Iteration 80 with variant 1 =====
#
# Not interleaved: 2
# Interleaved with one: 81
# Interleaved with two or more: 1102
#
#
#
# ===== Start Iteration 80 with variant 2 =====
#
# Not interleaved: 5
# Interleaved with one: 65
# Interleaved with two or more: 1115
#
#
#
# ===== Start Iteration 80 with variant 3 =====
#
# Not interleaved: 6
# Interleaved with one: 79
# Interleaved with two or more: 1100
#
#
#
# ===== Start Iteration 80 with variant 4 =====
#
# Not interleaved: 1
# Interleaved with one: 99
# Interleaved with two or more: 1085
#
#
#
# ===== Start Iteration 80 with variant 5 =====
#
# Not interleaved: 1
# Interleaved with one: 32
# Interleaved with two or more: 1152
#
# ===== Start Iteration 81 =====
#
#
# ===== Start Iteration 81 with variant 1 =====
#
# Not interleaved: 3
# Interleaved with one: 52
# Interleaved with two or more: 1310
#
#
#
# ===== Start Iteration 81 with variant 2 =====
#
# Not interleaved: 1
# Interleaved with one: 60
# Interleaved with two or more: 1304
#
#
#
# ===== Start Iteration 81 with variant 3 =====
#
# Not interleaved: 0
# Interleaved with one: 8
# Interleaved with two or more: 1357
#
#
#
# ===== Start Iteration 81 with variant 4 =====
#
# Not interleaved: 0
# Interleaved with one: 33
# Interleaved with two or more: 1332
#
#
#
# ===== Start Iteration 81 with variant 5 =====
#
# Not interleaved: 0
# Interleaved with one: 41
# Interleaved with two or more: 1324
#
# ===== Start Iteration 82 =====
#
#
# ===== Start Iteration 82 with variant 1 =====
#
# Not interleaved: 60
# Interleaved with one: 180
# Interleaved with two or more: 245
#
#
#
# ===== Start Iteration 82 with variant 2 =====
#
# Not interleaved: 36
# Interleaved with one: 228
# Interleaved with two or more: 221
#
#
#
# ===== Start Iteration 82 with variant 3 =====
#
# Not interleaved: 53
# Interleaved with one: 275
# Interleaved with two or more: 157
#
#
#
# ===== Start Iteration 82 with variant 4 =====
#
# Not interleaved: 10
# Interleaved with one: 177
# Interleaved with two or more: 298
#
#
#
# ===== Start Iteration 82 with variant 5 =====
#
# Not interleaved: 52
# Interleaved with one: 261
# Interleaved with two or more: 172
#
# ===== Start Iteration 83 =====
#
#
# ===== Start Iteration 83 with variant 1 =====
#
# Not interleaved: 2
# Interleaved with one: 62
# Interleaved with two or more: 1347
#
#
#
# ===== Start Iteration 83 with variant 2 =====
#
# Not interleaved: 3
# Interleaved with one: 73
# Interleaved with two or more: 1335
#
#
#
# ===== Start Iteration 83 with variant 3 =====
#
# Not interleaved: 5
# Interleaved with one: 63
# Interleaved with two or more: 1343
#
#
#
# ===== Start Iteration 83 with variant 4 =====
#
# Not interleaved: 6
# Interleaved with one: 64
# Interleaved with two or more: 1341
#
#
#
# ===== Start Iteration 83 with variant 5 =====
#
# Not interleaved: 10
# Interleaved with one: 63
# Interleaved with two or more: 1338
#
# ===== Start Iteration 84 =====
#
#
# ===== Start Iteration 84 with variant 1 =====
#
# Not interleaved: 68
# Interleaved with one: 683
# Interleaved with two or more: 352
#
#
#
# ===== Start Iteration 84 with variant 2 =====
#
# Not interleaved: 67
# Interleaved with one: 686
# Interleaved with two or more: 350
#
#
#
# ===== Start Iteration 84 with variant 3 =====
#
# Not interleaved: 69
# Interleaved with one: 683
# Interleaved with two or more: 351
#
#
#
# ===== Start Iteration 84 with variant 4 =====
#
# Not interleaved: 68
# Interleaved with one: 684
# Interleaved with two or more: 351
#
#
#
# ===== Start Iteration 84 with variant 5 =====
#
# Not interleaved: 68
# Interleaved with one: 685
# Interleaved with two or more: 350
#
# ===== Start Iteration 85 =====
#
#
# ===== Start Iteration 85 with variant 1 =====
#
# Not interleaved: 18
# Interleaved with one: 71
# Interleaved with two or more: 592
#
#
#
# ===== Start Iteration 85 with variant 2 =====
#
# Not interleaved: 19
# Interleaved with one: 119
# Interleaved with two or more: 543
#
#
#
# ===== Start Iteration 85 with variant 3 =====
#
# Not interleaved: 32
# Interleaved with one: 158
# Interleaved with two or more: 491
#
#
#
# ===== Start Iteration 85 with variant 4 =====
#
# Not interleaved: 14
# Interleaved with one: 62
# Interleaved with two or more: 605
#
#
#
# ===== Start Iteration 85 with variant 5 =====
#
# Not interleaved: 25
# Interleaved with one: 142
# Interleaved with two or more: 514
#
# ===== Start Iteration 86 =====
#
#
# ===== Start Iteration 86 with variant 1 =====
#
# Not interleaved: 19
# Interleaved with one: 197
# Interleaved with two or more: 1172
#
#
#
# ===== Start Iteration 86 with variant 2 =====
#
# Not interleaved: 15
# Interleaved with one: 403
# Interleaved with two or more: 970
#
#
#
# ===== Start Iteration 86 with variant 3 =====
#
# Not interleaved: 3
# Interleaved with one: 396
# Interleaved with two or more: 989
#
#
#
# ===== Start Iteration 86 with variant 4 =====
#
# Not interleaved: 13
# Interleaved with one: 459
# Interleaved with two or more: 916
#
#
#
# ===== Start Iteration 86 with variant 5 =====
#
# Not interleaved: 25
# Interleaved with one: 547
# Interleaved with two or more: 816
#
# ===== Start Iteration 87 =====
#
#
# ===== Start Iteration 87 with variant 1 =====
#
# Not interleaved: 107
# Interleaved with one: 430
# Interleaved with two or more: 332
#
#
#
# ===== Start Iteration 87 with variant 2 =====
#
# Not interleaved: 101
# Interleaved with one: 439
# Interleaved with two or more: 329
#
#
#
# ===== Start Iteration 87 with variant 3 =====
#
# Not interleaved: 106
# Interleaved with one: 434
# Interleaved with two or more: 329
#
#
#
# ===== Start Iteration 87 with variant 4 =====
#
# Not interleaved: 106
# Interleaved with one: 433
# Interleaved with two or more: 330
#
#
#
# ===== Start Iteration 87 with variant 5 =====
#
# Not interleaved: 105
# Interleaved with one: 435
# Interleaved with two or more: 329
#
# ===== Start Iteration 88 =====
#
#
# ===== Start Iteration 88 with variant 1 =====
#
# Not interleaved: 25
# Interleaved with one: 318
# Interleaved with two or more: 709
#
#
#
# ===== Start Iteration 88 with variant 2 =====
#
# Not interleaved: 10
# Interleaved with one: 199
# Interleaved with two or more: 843
#
#
#
# ===== Start Iteration 88 with variant 3 =====
#
# Not interleaved: 44
# Interleaved with one: 416
# Interleaved with two or more: 592
#
#
#
# ===== Start Iteration 88 with variant 4 =====
#
# Not interleaved: 80
# Interleaved with one: 99
# Interleaved with two or more: 873
#
#
#
# ===== Start Iteration 88 with variant 5 =====
#
# Not interleaved: 70
# Interleaved with one: 247
# Interleaved with two or more: 735
#
# ===== Start Iteration 89 =====
#
#
# ===== Start Iteration 89 with variant 1 =====
#
# Not interleaved: 32
# Interleaved with one: 213
# Interleaved with two or more: 507
#
#
#
# ===== Start Iteration 89 with variant 2 =====
#
# Not interleaved: 26
# Interleaved with one: 237
# Interleaved with two or more: 489
#
#
#
# ===== Start Iteration 89 with variant 3 =====
#
# Not interleaved: 21
# Interleaved with one: 366
# Interleaved with two or more: 365
#
#
#
# ===== Start Iteration 89 with variant 4 =====
#
# Not interleaved: 9
# Interleaved with one: 357
# Interleaved with two or more: 386
#
#
#
# ===== Start Iteration 89 with variant 5 =====
#
# Not interleaved: 102
# Interleaved with one: 242
# Interleaved with two or more: 408
#
# ===== Start Iteration 90 =====
#
#
# ===== Start Iteration 90 with variant 1 =====
#
# Not interleaved: 63
# Interleaved with one: 269
# Interleaved with two or more: 535
#
#
#
# ===== Start Iteration 90 with variant 2 =====
#
# Not interleaved: 98
# Interleaved with one: 272
# Interleaved with two or more: 497
#
#
#
# ===== Start Iteration 90 with variant 3 =====
#
# Not interleaved: 28
# Interleaved with one: 347
# Interleaved with two or more: 492
#
#
#
# ===== Start Iteration 90 with variant 4 =====
#
# Not interleaved: 56
# Interleaved with one: 423
# Interleaved with two or more: 388
#
#
#
# ===== Start Iteration 90 with variant 5 =====
#
# Not interleaved: 101
# Interleaved with one: 601
# Interleaved with two or more: 165
#
# ===== Start Iteration 91 =====
#
#
# ===== Start Iteration 91 with variant 1 =====
#
# Not interleaved: 12
# Interleaved with one: 212
# Interleaved with two or more: 923
#
#
#
# ===== Start Iteration 91 with variant 2 =====
#
# Not interleaved: 20
# Interleaved with one: 179
# Interleaved with two or more: 948
#
#
#
# ===== Start Iteration 91 with variant 3 =====
#
# Not interleaved: 3
# Interleaved with one: 44
# Interleaved with two or more: 1100
#
#
#
# ===== Start Iteration 91 with variant 4 =====
#
# Not interleaved: 5
# Interleaved with one: 220
# Interleaved with two or more: 922
#
#
#
# ===== Start Iteration 91 with variant 5 =====
#
# Not interleaved: 9
# Interleaved with one: 246
# Interleaved with two or more: 892
#
# ===== Start Iteration 92 =====
#
#
# ===== Start Iteration 92 with variant 1 =====
#
# Not interleaved: 17
# Interleaved with one: 152
# Interleaved with two or more: 795
#
#
#
# ===== Start Iteration 92 with variant 2 =====
#
# Not interleaved: 15
# Interleaved with one: 137
# Interleaved with two or more: 812
#
#
#
# ===== Start Iteration 92 with variant 3 =====
#
# Not interleaved: 7
# Interleaved with one: 133
# Interleaved with two or more: 824
#
#
#
# ===== Start Iteration 92 with variant 4 =====
#
# Not interleaved: 7
# Interleaved with one: 64
# Interleaved with two or more: 893
#
#
#
# ===== Start Iteration 92 with variant 5 =====
#
# Not interleaved: 19
# Interleaved with one: 237
# Interleaved with two or more: 708
#
# ===== Start Iteration 93 =====
#
#
# ===== Start Iteration 93 with variant 1 =====
#
# Not interleaved: 217
# Interleaved with one: 219
# Interleaved with two or more: 310
#
#
#
# ===== Start Iteration 93 with variant 2 =====
#
# Not interleaved: 219
# Interleaved with one: 218
# Interleaved with two or more: 309
#
#
#
# ===== Start Iteration 93 with variant 3 =====
#
# Not interleaved: 217
# Interleaved with one: 220
# Interleaved with two or more: 309
#
#
#
# ===== Start Iteration 93 with variant 4 =====
#
# Not interleaved: 215
# Interleaved with one: 223
# Interleaved with two or more: 308
#
#
#
# ===== Start Iteration 93 with variant 5 =====
#
# Not interleaved: 216
# Interleaved with one: 220
# Interleaved with two or more: 310
#
# ===== Start Iteration 94 =====
#
#
# ===== Start Iteration 94 with variant 1 =====
#
# Not interleaved: 30
# Interleaved with one: 150
# Interleaved with two or more: 612
#
#
#
# ===== Start Iteration 94 with variant 2 =====
#
# Not interleaved: 37
# Interleaved with one: 130
# Interleaved with two or more: 625
#
#
#
# ===== Start Iteration 94 with variant 3 =====
#
# Not interleaved: 22
# Interleaved with one: 97
# Interleaved with two or more: 673
#
#
#
# ===== Start Iteration 94 with variant 4 =====
#
# Not interleaved: 40
# Interleaved with one: 135
# Interleaved with two or more: 617
#
#
#
# ===== Start Iteration 94 with variant 5 =====
#
# Not interleaved: 30
# Interleaved with one: 172
# Interleaved with two or more: 590
#
# ===== Start Iteration 95 =====
#
#
# ===== Start Iteration 95 with variant 1 =====
#
# Not interleaved: 77
# Interleaved with one: 184
# Interleaved with two or more: 272
#
#
#
# ===== Start Iteration 95 with variant 2 =====
#
# Not interleaved: 81
# Interleaved with one: 182
# Interleaved with two or more: 270
#
#
#
# ===== Start Iteration 95 with variant 3 =====
#
# Not interleaved: 79
# Interleaved with one: 182
# Interleaved with two or more: 272
#
#
#
# ===== Start Iteration 95 with variant 4 =====
#
# Not interleaved: 78
# Interleaved with one: 184
# Interleaved with two or more: 271
#
#
#
# ===== Start Iteration 95 with variant 5 =====
#
# Not interleaved: 79
# Interleaved with one: 183
# Interleaved with two or more: 271
#
# ===== Start Iteration 96 =====
#
#
# ===== Start Iteration 96 with variant 1 =====
#
# Not interleaved: 6
# Interleaved with one: 122
# Interleaved with two or more: 1423
#
#
#
# ===== Start Iteration 96 with variant 2 =====
#
# Not interleaved: 7
# Interleaved with one: 47
# Interleaved with two or more: 1497
#
#
#
# ===== Start Iteration 96 with variant 3 =====
#
# Not interleaved: 7
# Interleaved with one: 210
# Interleaved with two or more: 1334
#
#
#
# ===== Start Iteration 96 with variant 4 =====
#
# Not interleaved: 6
# Interleaved with one: 69
# Interleaved with two or more: 1476
#
#
#
# ===== Start Iteration 96 with variant 5 =====
#
# Not interleaved: 10
# Interleaved with one: 84
# Interleaved with two or more: 1457
#
# ===== Start Iteration 97 =====
#
#
# ===== Start Iteration 97 with variant 1 =====
#
# Not interleaved: 1
# Interleaved with one: 77
# Interleaved with two or more: 1412
#
#
#
# ===== Start Iteration 97 with variant 2 =====
#
# Not interleaved: 6
# Interleaved with one: 73
# Interleaved with two or more: 1411
#
#
#
# ===== Start Iteration 97 with variant 3 =====
#
# Not interleaved: 10
# Interleaved with one: 68
# Interleaved with two or more: 1412
#
#
#
# ===== Start Iteration 97 with variant 4 =====
#
# Not interleaved: 15
# Interleaved with one: 183
# Interleaved with two or more: 1292
#
#
#
# ===== Start Iteration 97 with variant 5 =====
#
# Not interleaved: 10
# Interleaved with one: 120
# Interleaved with two or more: 1360
#
# ===== Start Iteration 98 =====
#
#
# ===== Start Iteration 98 with variant 1 =====
#
# Not interleaved: 28
# Interleaved with one: 114
# Interleaved with two or more: 599
#
#
#
# ===== Start Iteration 98 with variant 2 =====
#
# Not interleaved: 18
# Interleaved with one: 494
# Interleaved with two or more: 229
#
#
#
# ===== Start Iteration 98 with variant 3 =====
#
# Not interleaved: 11
# Interleaved with one: 177
# Interleaved with two or more: 553
#
#
#
# ===== Start Iteration 98 with variant 4 =====
#
# Not interleaved: 14
# Interleaved with one: 281
# Interleaved with two or more: 446
#
#
#
# ===== Start Iteration 98 with variant 5 =====
#
# Not interleaved: 15
# Interleaved with one: 174
# Interleaved with two or more: 552
#
# ===== Start Iteration 99 =====
#
#
# ===== Start Iteration 99 with variant 1 =====
#
# Not interleaved: 16
# Interleaved with one: 159
# Interleaved with two or more: 890
#
#
#
# ===== Start Iteration 99 with variant 2 =====
#
# Not interleaved: 15
# Interleaved with one: 61
# Interleaved with two or more: 989
#
#
#
# ===== Start Iteration 99 with variant 3 =====
#
# Not interleaved: 25
# Interleaved with one: 90
# Interleaved with two or more: 950
#
#
#
# ===== Start Iteration 99 with variant 4 =====
#
# Not interleaved: 25
# Interleaved with one: 214
# Interleaved with two or more: 826
#
#
#
# ===== Start Iteration 99 with variant 5 =====
#
# Not interleaved: 14
# Interleaved with one: 226
# Interleaved with two or more: 825
#
# ===== Start Iteration 100 =====
#
#
# ===== Start Iteration 100 with variant 1 =====
#
# Not interleaved: 7
# Interleaved with one: 107
# Interleaved with two or more: 995
#
#
#
# ===== Start Iteration 100 with variant 2 =====
#
# Not interleaved: 8
# Interleaved with one: 60
# Interleaved with two or more: 1041
#
#
#
# ===== Start Iteration 100 with variant 3 =====
#
# Not interleaved: 14
# Interleaved with one: 83
# Interleaved with two or more: 1012
#
#
#
# ===== Start Iteration 100 with variant 4 =====
#
# Not interleaved: 2
# Interleaved with one: 155
# Interleaved with two or more: 952
#
#
#
# ===== Start Iteration 100 with variant 5 =====
#
# Not interleaved: 1
# Interleaved with one: 57
# Interleaved with two or more: 1051

# %%
# Convert to DataFrame
df = pd.DataFrame(interleaved_results)
# ---- Add Average Row at Bottom ----
avg_row = {
    'iteration': 'AVERAGE',
    'not_interleaved': df['not_interleaved'].mean(),
    'interleaved_with_one': df['interleaved_with_one'].mean(),
    'interleaved_with_two_or_more': df['interleaved_with_two_or_more'].mean(),
    'avg_not_interleaved': df['avg_not_interleaved'].mean(),
    'avg_interleaved': df['avg_interleaved'].mean()
}
df = pd.concat([df, pd.DataFrame([avg_row])], ignore_index=True)
df.to_csv(f"out/results/interleave_stats_noise_{noise_level}.csv", index=False)
print("Saved to interleave_stats.csv")
# Out:
# Saved to interleave_stats.csv

# %%
# # Save the updated document
# doc.save(filename)
# print(f"✔ Appended results to {filename}")

# %%
# technique = "Our"
# noise_level = 0
# num_iterations = 10  # or however many you want
# results_file_name = f'{technique}_all_results_noise_{noise_level}.xlsx'
# results_dir = "out/results/"
# os.makedirs(results_dir) if not os.path.exists(results_dir) else None
# output_dir = f"Transformed_Logs_and_Results/{technique}/Transformed_Log_With_Noise_{noise_level}"

# all_results = []
# input_dir = "Saved_Logs"
# logs = pd.read_csv(f"{input_dir}/gt_labeled_all_routine_logs.csv", low_memory=False)


# for i in range(1, num_iterations+1):
#     segment_log, random_logs, random_numbers, doc = process_random_logs(logs, document=doc, variance_criteria='max')
#     segment_log.to_csv(f"{output_dir}/segment_log{i}.csv", index=False)
#     random_logs.to_csv(f"{output_dir}/unsegment_log{i}.csv", index=False)
    
#     doc = plot_interleaved_routines(segment_log, random_numbers, doc, interleaved_only=False)
#     plot_trace_interleaving_cases(segment_log)
    
#     dfg = grf.discover_dfg(random_logs)
    
#     G_Directed = grf.get_Network_Graph(dfg)
#     # G_Undirected = grf.to_Undirected(G_Directed, plot_graph=False, plot_matrix=False)
    
#     # G_Directed_Scored1 = grf.get_scored1_grpah_directed(G_Directed)
#     # G_Undirected_Scored1 = grf.to_Undirected(G_Directed_Scored1, output_filename="Graph_Matrix_UnDirected_Score1.csv")
    
#     G_Directed_Scored2 = grf.get_scored2_grpah_directed(G_Directed)
#     # G_Undirected_Scored2 = grf.to_Undirected(G_Directed_Scored2, output_filename="Graph_Matrix_UnDirected_Score2.csv")
    
#     doc.add_heading('Infomap Clustering with scored2 directed graph', level=2)
#     infomap_clusters, doc = grf.infomap_clustering(G_Directed_Scored2, document=doc, MRT=4.0)
    
#     results_dict = evaluate_clusters_with_jc(infomap_clusters, random_logs)
#     results_dict = append_averages_to_results(results_dict, random_numbers)
#     all_results.append(results_dict)
    
#     doc = display_and_export_results_doc(results_dict, doc, table_title="Cluster Evaluation Summary (Infomap)")

# display_and_export_results_xlx(all_results, results_dir, results_file_name)
