# %%
# !pip install python-docx

# %%
import os
import random
import pandas as pd
from docx import Document
from docx.enum.text import WD_ALIGN_PARAGRAPH


from Utils.utils1 import *
import Utils.graph_functions as grf

import warnings
warnings.filterwarnings('ignore')

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import normalized_mutual_info_score

import networkx as nx
from infomap import Infomap
from itertools import combinations
from collections import defaultdict
import community as community_louvain

import pm4py
from pm4py.objects.log.util import dataframe_utils
from pm4py.algo.discovery.dfg import algorithm as dfg_discovery
from pm4py.objects.conversion.log import converter as log_converter

# %%
filename = "Cluster-Results.docx"
Combination = 2
if os.path.exists(filename):
    doc = Document(filename)
else:
    doc = Document()
    centered_heading = doc.add_heading('Cluster Results', level=1)
    centered_heading.alignment = WD_ALIGN_PARAGRAPH.CENTER

centered_heading = doc.add_heading(f'Iteration {Combination}', level=3)
centered_heading.alignment = WD_ALIGN_PARAGRAPH.CENTER

# %%
# === RUN MODE OPTIONS ===
# 1: Use already saved logs
# 2: Use specified routines
# 3: New random selection
run_mode = 1  # Set to 1, 2, or 3

specified_routines = [52, 66, 85]  # Only used if run_mode == 2

technique = "Our"
noise_level = 0
results_file_name = f'{technique}_all_results_noise_{noise_level}.xlsx'
results_dir = "out/results/"
os.makedirs(results_dir) if not os.path.exists(results_dir) else None
output_dir = f"Transformed_Logs_and_Results/{technique}/Transformed_Log_With_Noise_{noise_level}"

interleaved_results = []
all_results = []
all_iteration_metadata = []  # Add this line to collect metadata
input_dir = "Saved_Logs"
logs = pd.read_csv(f"{input_dir}/gt_labeled_all_routine_logs.csv", low_memory=False)
num_iterations = 1 if run_mode == 2 else 100  # Only one iteration for specified routines

for i in range(1, num_iterations + 1):
    print(f"===== iteration {i} =====")
    if run_mode == 1:
        # Option 1: Use already saved logs
        segment_log = pd.read_csv(f"{output_dir}/segment_log{i}.csv")
        random_logs = pd.read_csv(f"{output_dir}/unsegment_log{i}.csv")
        random_numbers = list(segment_log['routine_type'].unique())
        iteration_metadata = None  # No metadata for saved logs
    elif run_mode == 2:
        # Option 2: Use specified routines (only one iteration)
        segment_log, random_logs, random_numbers, doc, iteration_metadata = process_random_logs(
            logs, document=doc, variance_criteria='max', specified_routines=specified_routines
        )
        if segment_log is None:
            print("Specified routines did not yield enough traces. Exiting.")
            break
    else:
        print("\n","="*5, f"Start Iteration {i}:", "="*5)
        # Option 3: New random selection (current behavior)
        segment_log, random_logs, random_numbers, doc, iteration_metadata = process_random_logs(
            logs, document=doc, variance_criteria='min'
        )
        # segment_log.to_csv(f"{output_dir}/segment_log{i}.csv", index=False)
        # random_logs.to_csv(f"{output_dir}/unsegment_log{i}.csv", index=False)

    trace_interleaved_counts = count_trace_interleaving_cases(segment_log)
    trace_interleaved_counts = update_avg_counts(trace_interleaved_counts)
    trace_interleaved_counts['iteration'] = f"iteration_{i}"
    interleaved_results.append(trace_interleaved_counts)
    
#     # Store metadata for Excel export
#     all_iteration_metadata.append(iteration_metadata)

#     doc = plot_interleaved_routines(segment_log, random_numbers, doc, image_path=f"out/plots/interleaved_routines_plot{i}.png", interleaved_only=False)
#     plot_trace_interleaving_cases(segment_log, image_path=f"out/plots/trace_interleaving_cases_bar{i}.png")

#     dfg = grf.discover_dfg(random_logs)
#     G_Directed = grf.get_Network_Graph(dfg, output_filename=f"Graph_Matrix_Directed{i}.csv")
#     G_Directed_Scored2 = grf.get_scored2_grpah_directed(G_Directed, output_filename=f"Graph_Matrix_UnDirected{i}.csv")

#     doc.add_heading('Infomap Clustering with scored2 directed graph', level=2)
#     infomap_clusters, doc = grf.infomap_clustering(G_Directed_Scored2, document=doc, MRT=4.0)

#     results_dict = evaluate_clusters_with_jc(infomap_clusters, segment_log)
#     results_dict = append_averages_to_results(results_dict, random_numbers)
#     all_results.append(results_dict)

#     doc = display_and_export_results_doc(results_dict, doc, table_title="Cluster Evaluation Summary (Infomap)")

# display_and_export_results_xlx(all_results, all_iteration_metadata, results_dir, results_file_name)
# plot_jc_boxplot_by_non_interleaving_bins("out/results/Our_all_results_noise_0_new.xlsx")
# Out:
# ===== iteration 1 =====
#
# Not interleaved: 260
# Interleaved with one: 636
# Interleaved with two or more: 311
#
# ===== iteration 2 =====
#
# Not interleaved: 545
# Interleaved with one: 326
# Interleaved with two or more: 60
#
# ===== iteration 3 =====
#
# Not interleaved: 329
# Interleaved with one: 311
# Interleaved with two or more: 63
#
# ===== iteration 4 =====
#
# Not interleaved: 558
# Interleaved with one: 322
# Interleaved with two or more: 71
#
# ===== iteration 5 =====
#
# Not interleaved: 120
# Interleaved with one: 579
# Interleaved with two or more: 503
#
# ===== iteration 6 =====
#
# Not interleaved: 419
# Interleaved with one: 189
# Interleaved with two or more: 16
#
# ===== iteration 7 =====
#
# Not interleaved: 136
# Interleaved with one: 747
# Interleaved with two or more: 703
#
# ===== iteration 8 =====
#
# Not interleaved: 182
# Interleaved with one: 533
# Interleaved with two or more: 363
#
# ===== iteration 9 =====
#
# Not interleaved: 233
# Interleaved with one: 99
# Interleaved with two or more: 17
#
# ===== iteration 10 =====
#
# Not interleaved: 95
# Interleaved with one: 504
# Interleaved with two or more: 417
#
# ===== iteration 11 =====
#
# Not interleaved: 255
# Interleaved with one: 607
# Interleaved with two or more: 432
#
# ===== iteration 12 =====
#
# Not interleaved: 322
# Interleaved with one: 515
# Interleaved with two or more: 211
#
# ===== iteration 13 =====
#
# Not interleaved: 262
# Interleaved with one: 204
# Interleaved with two or more: 293
#
# ===== iteration 14 =====
#
# Not interleaved: 228
# Interleaved with one: 147
# Interleaved with two or more: 17
#
# ===== iteration 15 =====
#
# Not interleaved: 528
# Interleaved with one: 440
# Interleaved with two or more: 73
#
# ===== iteration 16 =====
#
# Not interleaved: 94
# Interleaved with one: 549
# Interleaved with two or more: 851
#
# ===== iteration 17 =====
#
# Not interleaved: 535
# Interleaved with one: 317
# Interleaved with two or more: 42
#
# ===== iteration 18 =====
#
# Not interleaved: 61
# Interleaved with one: 365
# Interleaved with two or more: 330
#
# ===== iteration 19 =====
#
# Not interleaved: 282
# Interleaved with one: 927
# Interleaved with two or more: 187
#
# ===== iteration 20 =====
#
# Not interleaved: 411
# Interleaved with one: 604
# Interleaved with two or more: 130
#
# ===== iteration 21 =====
#
# Not interleaved: 291
# Interleaved with one: 530
# Interleaved with two or more: 146
#
# ===== iteration 22 =====
#
# Not interleaved: 61
# Interleaved with one: 365
# Interleaved with two or more: 330
#
# ===== iteration 23 =====
#
# Not interleaved: 270
# Interleaved with one: 619
# Interleaved with two or more: 405
#
# ===== iteration 24 =====
#
# Not interleaved: 149
# Interleaved with one: 619
# Interleaved with two or more: 673
#
# ===== iteration 25 =====
#
# Not interleaved: 144
# Interleaved with one: 690
# Interleaved with two or more: 752
#
# ===== iteration 26 =====
#
# Not interleaved: 191
# Interleaved with one: 756
# Interleaved with two or more: 568
#
# ===== iteration 27 =====
#
# Not interleaved: 161
# Interleaved with one: 774
# Interleaved with two or more: 638
#
# ===== iteration 28 =====
#
# Not interleaved: 346
# Interleaved with one: 517
# Interleaved with two or more: 145
#
# ===== iteration 29 =====
#
# Not interleaved: 272
# Interleaved with one: 177
# Interleaved with two or more: 44
#
# ===== iteration 30 =====
#
# Not interleaved: 99
# Interleaved with one: 441
# Interleaved with two or more: 326
#
# ===== iteration 31 =====
#
# Not interleaved: 86
# Interleaved with one: 546
# Interleaved with two or more: 367
#
# ===== iteration 32 =====
#
# Not interleaved: 426
# Interleaved with one: 633
# Interleaved with two or more: 336
#
# ===== iteration 33 =====
#
# Not interleaved: 157
# Interleaved with one: 796
# Interleaved with two or more: 603
#
# ===== iteration 34 =====
#
# Not interleaved: 200
# Interleaved with one: 646
# Interleaved with two or more: 288
#
# ===== iteration 35 =====
#
# Not interleaved: 177
# Interleaved with one: 503
# Interleaved with two or more: 475
#
# ===== iteration 36 =====
#
# Not interleaved: 238
# Interleaved with one: 131
# Interleaved with two or more: 31
#
# ===== iteration 37 =====
#
# Not interleaved: 637
# Interleaved with one: 340
# Interleaved with two or more: 23
#
# ===== iteration 38 =====
#
# Not interleaved: 135
# Interleaved with one: 219
# Interleaved with two or more: 309
#
# ===== iteration 39 =====
#
# Not interleaved: 245
# Interleaved with one: 415
# Interleaved with two or more: 144
#
# ===== iteration 40 =====
#
# Not interleaved: 533
# Interleaved with one: 394
# Interleaved with two or more: 54
#
# ===== iteration 41 =====
#
# Not interleaved: 249
# Interleaved with one: 790
# Interleaved with two or more: 228
#
# ===== iteration 42 =====
#
# Not interleaved: 256
# Interleaved with one: 941
# Interleaved with two or more: 191
#
# ===== iteration 43 =====
#
# Not interleaved: 271
# Interleaved with one: 535
# Interleaved with two or more: 224
#
# ===== iteration 44 =====
#
# Not interleaved: 369
# Interleaved with one: 500
# Interleaved with two or more: 187
#
# ===== iteration 45 =====
#
# Not interleaved: 336
# Interleaved with one: 470
# Interleaved with two or more: 108
#
# ===== iteration 46 =====
#
# Not interleaved: 536
# Interleaved with one: 268
# Interleaved with two or more: 23
#
# ===== iteration 47 =====
#
# Not interleaved: 134
# Interleaved with one: 334
# Interleaved with two or more: 269
#
# ===== iteration 48 =====
#
# Not interleaved: 143
# Interleaved with one: 517
# Interleaved with two or more: 352
#
# ===== iteration 49 =====
#
# Not interleaved: 282
# Interleaved with one: 205
# Interleaved with two or more: 33
#
# ===== iteration 50 =====
#
# Not interleaved: 326
# Interleaved with one: 377
# Interleaved with two or more: 51
#
# ===== iteration 51 =====
#
# Not interleaved: 219
# Interleaved with one: 340
# Interleaved with two or more: 122
#
# ===== iteration 52 =====
#
# Not interleaved: 181
# Interleaved with one: 427
# Interleaved with two or more: 321
#
# ===== iteration 53 =====
#
# Not interleaved: 176
# Interleaved with one: 658
# Interleaved with two or more: 300
#
# ===== iteration 54 =====
#
# Not interleaved: 239
# Interleaved with one: 362
# Interleaved with two or more: 96
#
# ===== iteration 55 =====
#
# Not interleaved: 122
# Interleaved with one: 642
# Interleaved with two or more: 634
#
# ===== iteration 56 =====
#
# Not interleaved: 158
# Interleaved with one: 260
# Interleaved with two or more: 256
#
# ===== iteration 57 =====
#
# Not interleaved: 35
# Interleaved with one: 0
# Interleaved with two or more: 310
#
# ===== iteration 58 =====
#
# Not interleaved: 293
# Interleaved with one: 613
# Interleaved with two or more: 337
#
# ===== iteration 59 =====
#
# Not interleaved: 298
# Interleaved with one: 526
# Interleaved with two or more: 224
#
# ===== iteration 60 =====
#
# Not interleaved: 317
# Interleaved with one: 810
# Interleaved with two or more: 186
#
# ===== iteration 61 =====
#
# Not interleaved: 595
# Interleaved with one: 369
# Interleaved with two or more: 53
#
# ===== iteration 62 =====
#
# Not interleaved: 246
# Interleaved with one: 622
# Interleaved with two or more: 423
#
# ===== iteration 63 =====
#
# Not interleaved: 642
# Interleaved with one: 440
# Interleaved with two or more: 95
#
# ===== iteration 64 =====
#
# Not interleaved: 138
# Interleaved with one: 352
# Interleaved with two or more: 313
#
# ===== iteration 65 =====
#
# Not interleaved: 187
# Interleaved with one: 827
# Interleaved with two or more: 449
#
# ===== iteration 66 =====
#
# Not interleaved: 86
# Interleaved with one: 546
# Interleaved with two or more: 367
#
# ===== iteration 67 =====
#
# Not interleaved: 581
# Interleaved with one: 356
# Interleaved with two or more: 80
#
# ===== iteration 68 =====
#
# Not interleaved: 80
# Interleaved with one: 464
# Interleaved with two or more: 565
#
# ===== iteration 69 =====
#
# Not interleaved: 145
# Interleaved with one: 692
# Interleaved with two or more: 746
#
# ===== iteration 70 =====
#
# Not interleaved: 99
# Interleaved with one: 492
# Interleaved with two or more: 425
#
# ===== iteration 71 =====
#
# Not interleaved: 234
# Interleaved with one: 91
# Interleaved with two or more: 13
#
# ===== iteration 72 =====
#
# Not interleaved: 163
# Interleaved with one: 757
# Interleaved with two or more: 791
#
# ===== iteration 73 =====
#
# Not interleaved: 329
# Interleaved with one: 433
# Interleaved with two or more: 91
#
# ===== iteration 74 =====
#
# Not interleaved: 291
# Interleaved with one: 524
# Interleaved with two or more: 215
#
# ===== iteration 75 =====
#
# Not interleaved: 352
# Interleaved with one: 622
# Interleaved with two or more: 222
#
# ===== iteration 76 =====
#
# Not interleaved: 500
# Interleaved with one: 355
# Interleaved with two or more: 79
#
# ===== iteration 77 =====
#
# Not interleaved: 269
# Interleaved with one: 446
# Interleaved with two or more: 134
#
# ===== iteration 78 =====
#
# Not interleaved: 299
# Interleaved with one: 295
# Interleaved with two or more: 67
#
# ===== iteration 79 =====
#
# Not interleaved: 206
# Interleaved with one: 220
# Interleaved with two or more: 42
#
# ===== iteration 80 =====
#
# Not interleaved: 149
# Interleaved with one: 503
# Interleaved with two or more: 533
#
# ===== iteration 81 =====
#
# Not interleaved: 57
# Interleaved with one: 456
# Interleaved with two or more: 852
#
# ===== iteration 82 =====
#
# Not interleaved: 253
# Interleaved with one: 189
# Interleaved with two or more: 43
#
# ===== iteration 83 =====
#
# Not interleaved: 98
# Interleaved with one: 579
# Interleaved with two or more: 734
#
# ===== iteration 84 =====
#
# Not interleaved: 70
# Interleaved with one: 684
# Interleaved with two or more: 349
#
# ===== iteration 85 =====
#
# Not interleaved: 227
# Interleaved with one: 345
# Interleaved with two or more: 109
#
# ===== iteration 86 =====
#
# Not interleaved: 273
# Interleaved with one: 923
# Interleaved with two or more: 192
#
# ===== iteration 87 =====
#
# Not interleaved: 108
# Interleaved with one: 433
# Interleaved with two or more: 328
#
# ===== iteration 88 =====
#
# Not interleaved: 486
# Interleaved with one: 456
# Interleaved with two or more: 110
#
# ===== iteration 89 =====
#
# Not interleaved: 383
# Interleaved with one: 313
# Interleaved with two or more: 56
#
# ===== iteration 90 =====
#
# Not interleaved: 546
# Interleaved with one: 285
# Interleaved with two or more: 36
#
# ===== iteration 91 =====
#
# Not interleaved: 164
# Interleaved with one: 686
# Interleaved with two or more: 297
#
# ===== iteration 92 =====
#
# Not interleaved: 282
# Interleaved with one: 456
# Interleaved with two or more: 226
#
# ===== iteration 93 =====
#
# Not interleaved: 220
# Interleaved with one: 218
# Interleaved with two or more: 308
#
# ===== iteration 94 =====
#
# Not interleaved: 312
# Interleaved with one: 368
# Interleaved with two or more: 112
#
# ===== iteration 95 =====
#
# Not interleaved: 83
# Interleaved with one: 180
# Interleaved with two or more: 270
#
# ===== iteration 96 =====
#
# Not interleaved: 191
# Interleaved with one: 743
# Interleaved with two or more: 617
#
# ===== iteration 97 =====
#
# Not interleaved: 203
# Interleaved with one: 728
# Interleaved with two or more: 559
#
# ===== iteration 98 =====
#
# Not interleaved: 346
# Interleaved with one: 322
# Interleaved with two or more: 73
#
# ===== iteration 99 =====
#
# Not interleaved: 290
# Interleaved with one: 571
# Interleaved with two or more: 204
#
# ===== iteration 100 =====
#
# Not interleaved: 77
# Interleaved with one: 489
# Interleaved with two or more: 543

# %%
# Convert to DataFrame
df = pd.DataFrame(interleaved_results)
# ---- Add Average Row at Bottom ----
avg_row = {
    'iteration': 'AVERAGE',
    'not_interleaved': df['not_interleaved'].mean(),
    'interleaved_with_one': df['interleaved_with_one'].mean(),
    'interleaved_with_two_or_more': df['interleaved_with_two_or_more'].mean(),
    'avg_not_interleaved': df['avg_not_interleaved'].mean(),
    'avg_interleaved': df['avg_interleaved'].mean()
}
df = pd.concat([df, pd.DataFrame([avg_row])], ignore_index=True)
df.to_csv(f"out/results/interleave_stats_noise_{noise_level}.csv", index=False)
print("Saved to interleave_stats.csv")
# Out:
# Saved to interleave_stats.csv

# %%
# # Save the updated document
# doc.save(filename)
# print(f"✔ Appended results to {filename}")
